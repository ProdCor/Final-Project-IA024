# %%
TEST_PATH = '../input/Raw Text/FAQ/faq.json'
LEGIS_PATH = '../input/Raw Text/Legislation/output_legislation_2.json'
NORMS_PATH = '../input/Raw Text/Norms/output_prof3_v11_2.json'

# %%
import json

test_set = json.load(open(TEST_PATH, 'r'))
legis_set = json.load(open(LEGIS_PATH, 'r'))
norms_set = json.load(open(NORMS_PATH, 'r'))

context_set = {**norms_set, **legis_set}

# %%
perg_resposta_esperada = []

for i in range(len(test_set)):
  pr = test_set[i]

  pergunta = pr['question']
  resposta = pr['answer']
  contexto = pr['context']
  
 
  perg_resposta_esperada.append({"pergunta": pergunta, "resposta": resposta, "contexto": contexto})

  if i < 3:
    print(f"{i}: {pergunta}\n{resposta}\n{contexto}")
    print('----------------------------------------------------------------------')
# Out:
# 0: Em quais hipóteses a Procuradoria Geral pode exercer a representação judicial e extrajudicial de servidores da UNICAMP?
# A Procuradoria Geral da UNICAMP integra a Advocacia Pública e está vinculada à Procuradoria Geral do Estado, para fins de atuação uniforme e coordenada, nos termos do artigo 101 da Constituição Estadual. Além disso, é o órgão de representação jurídica da Universidade e de assessoramento jurídico da Reitoria, consoante prevê o artigo 95 do Regimento Geral da UNICAMP. Desta forma, conforme previsão regimental, a Procuradoria Geral tem a função institucional de defender os interesses da universidade, enquanto autarquia estadual, estritamente vinculada ao atendimento do interesse público. A representação judicial ou extrajudicial de servidor com vínculo funcional permanente poderá ocorrer em caráter excepcional, nas hipóteses em que o ato impugnado decorrer do exercício de suas atribuições constitucionais, legais ou regulamentares, quando o ato praticado tiver seguido a orientação jurídica da Procuradoria e desde que não haja conflito de interesses, sempre com autorização expressa do Reitor.
# ['Constituição Estadual SP', 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS']
# ----------------------------------------------------------------------
# 1: Como ocorrem as atividades de cooperação, pesquisa, ensino, extensão e prestação de serviços entre a Unicamp e terceiros, pessoas físicas ou jurídicas?
# Nos termos do art. 1° da Deliberação CONSU-A-016/2022, a atuação da Universidade em atividades de cooperação, pesquisa, ensino, extensão e prestação de serviços junto a terceiros, pessoas físicas ou jurídicas, deve ocorrer mediante prévia celebração de convênios, contratos e instrumentos similares.
# ['Deliberação CONSU-A-016/2022']
# ----------------------------------------------------------------------
# 2: Qual é o procedimento para a celebração de convênios, contratos e instrumentos similares relativos às atividades de cooperação, pesquisa, ensino, extensão e prestação de serviços pela Unicamp?
# Na Unicamp, a celebração de convênios, contratos e instrumentos similares (aqui sempre referidos como “convênios”) é regulamentada pela Deliberação CONSU-A-016/2022. O servidor responsável pela proposta de convênio deve providenciar a abertura de um processo administrativo na Unidade ou Órgão onde a atividade principal será realizada, instruí-lo com os documentos indicados e tramitá-lo conforme o disposto na Deliberação CONSU-A-016/2022. Ao final da tramitação, se devidamente aprovado em todas as instâncias, o convênio será encaminhado para assinatura da autoridade competente.
# ['Deliberação CONSU-A-016/2022']
# ----------------------------------------------------------------------

# %%
all_titles = []
documents = []

for item in test_set:
    for context in item['context']:
        if context.lower() not in all_titles:
            all_titles.append(context.lower())
            documents.append({
                    "title": context,
                    "content": context_set[context] if context in context_set else item['answer']
                }
            )

# %%
# %%time
from tqdm import tqdm
import spacy
import pickle

nlp = spacy.blank("pt")
nlp.add_pipe("sentencizer")

stride = 2
max_length = 3

def window(documents, stride=2, max_length=3):
  treated_documents = []

  for j, document in enumerate(tqdm(documents)):
    doc_text = document['content']
    doc = nlp(doc_text)
    sentences = [sent.text.strip() for sent in doc.sents]
    for i in range(0, len(sentences), stride):
      segment = ' '.join(sentences[i:i + max_length])
      treated_documents.append({
          "title": document['title'],
          "contents": "[" + document['title'] + "]" + ": " + segment,
          "segment": segment
      })
      if i + max_length >= len(sentences):
        break
  return treated_documents


artigos_segmentados = window(documents)
# Out:
# 100%|██████████| 38/38 [00:02<00:00, 18.73it/s]
# CPU times: user 4.59 s, sys: 328 ms, total: 4.92 s
# Wall time: 3.89 s

# %%
# %%time
from collections import Counter
import array
import pickle
import math
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')

# Definição de uma classe para índice invertido
class IndiceInvertido:

  # Recebe 'tokenizar', uma função tokenizadora
  def __init__(self):
    # Cria um índice invertido vazio
    self.indice = {}
    # Cria um índice de tamanho de documentos vazio
    self.tamanho_doc = {}
    # Guarda o total de documentos adicionados
    self.n_docs = 0
    # Tokenizador
    self.stemmer = PorterStemmer()

  def tokenizar(self, texto):
    # Tokeniza
    tokens = word_tokenize(texto)
    # Converte para minúsculo, filtra stopwords e passa pelo Porter Stemer
    tokens = [self.stemmer.stem(token.lower()) for token in tokens if token.lower() not in stopwords.words('portuguese')] # changed to portuguese

    return tokens

  def adiciona_doc(self, id_doc, conteudo_doc=None):
    tokens = self.tokenizar(conteudo_doc)

    contador_tokens_do_documento = Counter(tokens)
    for token, n_ocorrencias in contador_tokens_do_documento.items():
      self.indice.setdefault(token, {"id_doc": [], "n_ocorrencias": array.array("L", [])})['id_doc'].append(id_doc)
      self.indice.setdefault(token, {"id_doc": [], "n_ocorrencias": array.array("L", [])})['n_ocorrencias'].append(n_ocorrencias)

    self.n_docs += 1
    self.tamanho_doc[id_doc] = len(tokens)

class BM25:

  def __init__(self, indiceInvertido=IndiceInvertido(), k1 = 0.9, b = 0.4, bias_adicionar_ao_idf = 0):
    self.indiceInvertido = indiceInvertido
    self.bias_adicionar_ao_idf = bias_adicionar_ao_idf
    self.calcula_tam_medio_doc_no_indice()
    self.k1 = k1
    self.b = b
    self.precalcula_idf()
    self.reinicia_score_dos_indices()

  def reinicia_score_dos_indices(self):
    for token in self.indiceInvertido.indice.keys():
      self.indiceInvertido.indice[token].pop('score', None)

  def calcula_tam_medio_doc_no_indice(self):
    self.avgdl = sum(self.indiceInvertido.tamanho_doc.values()) / self.indiceInvertido.n_docs

  def precalcula_idf(self):
    # Número de documento do corpus está presente no objeto indiceInvertido
    N = self.indiceInvertido.n_docs
    # Varre todos os tokens do índice. Os tokens são as chaves do indiceInvertido.indice
    for token in self.indiceInvertido.indice.keys():
      # O número de documentos que possui o token é calculado pelo tamanho da lista de id_doc:
      n_doc_token = len(self.indiceInvertido.indice[token]['id_doc'])
      # Isso já é o suficiente pra calcular o idf
      idf_token = math.log( ((self.indiceInvertido.n_docs - n_doc_token + 0.5)/(n_doc_token + 0.5)) + self.bias_adicionar_ao_idf )
      # E agora, vamos colocar essa informação no índice
      self.indiceInvertido.indice[token]['idf'] = idf_token

  def calcula_score_para_um_token_e_salva(self, token):
    # O cálculo do BM25 para determinada query é a multiplicação do idf pela frequência do termo no documento * (k1 + 1)
    # Além disso, é dividido pela frequencia do termo no documento + k1 * (1 - b + b * tamanho_doc/avgdl)
    idf = self.indiceInvertido.indice[token]['idf']
    # Juntando tudo, podemos calcular o score pelo BM25
    zip_id_freq = zip(self.indiceInvertido.indice[token]['id_doc'], self.indiceInvertido.indice[token]['n_ocorrencias'])
    bm25 = array.array("f", [ idf * freq_token_no_doc * (self.k1 + 1) / (freq_token_no_doc + self.k1 * (1 - self.b + self.b * self.indiceInvertido.tamanho_doc[id_doc] / self.avgdl)) for (id_doc, freq_token_no_doc) in zip_id_freq ])
    # Salva o bm25 no índice
    self.indiceInvertido.indice[token]['score'] = bm25

  def tokenizar(self, query):
    return self.indiceInvertido.tokenizar(query)

  def pesquisar(self, query):
    # Tokeniza a query
    tokens = self.tokenizar(query)

    # Se não tem token para ser pesquisado, retorna conjunto vazio
    if (len(tokens) == 0):
      return []

    # Guarda um dicionário onde a chave é o id do documento e o valor é o score desse documento para a query pesquisada
    docs_retornado_com_score = Counter({})

    # Faz a pesquisa de documentos. Para isso iteramos todos os tokens da query
    for token in tokens:
      # É possível que a query contenha algum termo que não foi indexado. Se isso ocorrer,
      # entende-se que a frequência desse token em qualquer documento é 0, já que não pode ser encontrado
      if token not in self.indiceInvertido.indice:
        continue

      # Pega a lista de documentos que será analisado
      docs_que_tem_token = self.indiceInvertido.indice[token]['id_doc']

      # Se for a primeira vez que esse token é pesquisado, é necessário calcular o score relacionado
      # a ele e salvar. Se já tiver sido feito antes, já podemos buscar o cálculo pronto (que funciona
      # como um cache. Isso é útil no caso de várias pesquisas seguidas)
      if 'score' not in self.indiceInvertido.indice[token].keys():
        self.calcula_score_para_um_token_e_salva(token)
      score_dos_docs_deste_token = self.indiceInvertido.indice[token]['score']

      # Agora já temos calculado o score de todos os documentos desse token. Só adiciona ao acumulador de score atual
      # docs_retornado_com_score += score_dos_docs_deste_token -> Se fosse usar dict direto no índice seria assim, mas a memória não está aguentando guardar os scores de ambos
      for id_doc, score_par_doc_token in zip(docs_que_tem_token, score_dos_docs_deste_token):
        docs_retornado_com_score[id_doc] += score_par_doc_token

    # Agora converte esse dict em uma lista de tuplas com a chave (id_doc) e valor (score_do_doc)
    docs_com_score = list(docs_retornado_com_score.items())

    # E ordena do mais relevante para o menos relevante
    return sorted(docs_com_score, key=lambda x: x[1], reverse=True)
# Out:
# CPU times: user 1.71 s, sys: 203 ms, total: 1.92 s
# Wall time: 1.73 s
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/victorgmoreno/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/victorgmoreno/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
iidx = IndiceInvertido()
iidx.tokenizar('Qual o maior planeta do sistema solar?')
# Out:
# ['maior', 'planeta', 'sistema', 'solar', '?']

# %%
# Se True, gera o índice invertido e salva em um pickle. Se False, apenas recupera o pickle do drive
GERAR_INDICE_INVERTIDO = True
ARQUIVO_INDICE_INVERTIDO = 'iidx_artigos_segmentados_6' # A função salva em 2 arquivos, então ela mesma coloca a extensão pickle

# Se True, gera as respostas. Se False, apenas recupera o pickle do drive
AGREGAR_DOCUMENTOS = True
ARQUIVO_AGREGADO = 'respostas_obtidas.pickle_9'

# %%
import pickle

def salvar_indice_em_arquivo_pickle(indice_invertido):
  nome_arquivo_base = f"{'../input/Raw Text/Rag Data/'}{ARQUIVO_INDICE_INVERTIDO}"

  with open(f'{nome_arquivo_base}_indice.pickle', 'wb') as f:
    pickle.dump(indice_invertido.indice, f)
  with open(f'{nome_arquivo_base}_tamanho_doc.pickle', 'wb') as f:
    pickle.dump(indice_invertido.tamanho_doc, f)

def recuperar_indice_em_arquivo_pickle():
  nome_arquivo_base = f"{'../input/Raw Text/Rag Data/'}{ARQUIVO_INDICE_INVERTIDO}"
  idx = IndiceInvertido()

  with open(f'{nome_arquivo_base}_indice.pickle', 'rb') as f:
    idx.indice = pickle.load(f)
  with open(f'{nome_arquivo_base}_tamanho_doc.pickle', 'rb') as f:
    idx.tamanho_doc = pickle.load(f)
  idx.n_docs = len(idx.tamanho_doc)

  return idx

# %%
# %%time
iidx = IndiceInvertido()

if GERAR_INDICE_INVERTIDO:
  # Vamos usar o próprio índice como um id para o segmento. Vai facilitar a vida depois
  # art_seg['contents'] tem o título e 3 frases do artigo
  for id, art_seg in enumerate(artigos_segmentados):
    iidx.adiciona_doc(id, art_seg['contents'])

    if id % 10000 == 0:
      print(f'{id} segmentos indexados')

  salvar_indice_em_arquivo_pickle(iidx)
else:
  iidx = recuperar_indice_em_arquivo_pickle()
# Out:
# 0 segmentos indexados
# CPU times: user 17.2 s, sys: 3.86 s, total: 21 s
# Wall time: 22.7 s

# %%
buscador = BM25(iidx, 0.82, 0.68, 1)
buscador = BM25(iidx)

# %%
print('Pergunta e resposta esperada: ')
print(perg_resposta_esperada[0])

resultado_bm25 = buscador.pesquisar(perg_resposta_esperada[0]['pergunta'])

print('-----------------------------------------------------------------')
print('10 primeiros conteúdos retornados pelo BM25\n')
for i in range(10):
  segmento_id = resultado_bm25[i][0]
  score = resultado_bm25[i][1]

  title = artigos_segmentados[segmento_id]['title']
  contents = artigos_segmentados[segmento_id]['contents']
  segment = artigos_segmentados[segmento_id]['segment']

  print(f'Segmento_id: {segmento_id}. Score: {score}')
  print(f"Title: {title}")
  print(f"Contents: {contents}")
  print('-----------------------------------------------------------------')
# Out:
# Pergunta e resposta esperada:
# {'pergunta': 'Em quais hipóteses a Procuradoria Geral pode exercer a representação judicial e extrajudicial de servidores da UNICAMP?', 'resposta': 'A Procuradoria Geral da UNICAMP integra a Advocacia Pública e está vinculada à Procuradoria Geral do Estado, para fins de atuação uniforme e coordenada, nos termos do artigo 101 da Constituição Estadual. Além disso, é o órgão de representação jurídica da Universidade e de assessoramento jurídico da Reitoria, consoante prevê o artigo 95 do Regimento Geral da UNICAMP. Desta forma, conforme previsão regimental, a Procuradoria Geral tem a função institucional de defender os interesses da universidade, enquanto autarquia estadual, estritamente vinculada ao atendimento do interesse público. A representação judicial ou extrajudicial de servidor com vínculo funcional permanente poderá ocorrer em caráter excepcional, nas hipóteses em que o ato impugnado decorrer do exercício de suas atribuições constitucionais, legais ou regulamentares, quando o ato praticado tiver seguido a orientação jurídica da Procuradoria e desde que não haja conflito de interesses, sempre com autorização expressa do Reitor.', 'contexto': ['Constituição Estadual SP', 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS']}
# -----------------------------------------------------------------
# 10 primeiros conteúdos retornados pelo BM25
#
# Segmento_id: 1992. Score: 13.84269380569458
# Title: Constituição Federal
# Contents: [Constituição Federal]: (Incluído pela Emenda Constitucional nº 45, de 2004)
#   Art. 129. São funções institucionais do Ministério Público:07/06/2024, 11:39 Constituição
# www.planalto.gov.br/ccivil_03/constituicao/constituicao.htm 91/226
# I - promover , privativamente, a ação penal pública, na forma da lei;
# II - zelar pelo efetivo respeito dos Poderes Públicos e dos serviços de relevância pública aos direitos assegurados nesta Constituição, promovendo as medidas necessárias
# a sua garantia;
# III - promover o inquérito civil e a ação civil pública, para a proteção do patrimônio público e social, do meio ambiente e de outros interesses difusos e coletivos;
# IV - promover a ação de inconstitucionalidade ou representação para fins de intervenção da União e dos Estados, nos casos previstos nesta Constituição;
# V - defender judicialmente os direitos e interesses das populações indígenas;
# VI - expedir notificações nos procedimentos administrativos de sua competência, requisitando informações e documentos para instruí-los, na forma da lei complementar
# respectiva;
# VII - exercer o controle externo da atividade policial, na forma da lei complementar mencionada no artigo anterior;
# VIII - requisitar diligências investigatórias e a instauração de inquérito policial, indicados os fundamentos jurídicos de suas manifestações processuais;
# IX - exerce r outras funções que lhe forem conferidas, desde que compatíveis com sua finalidade, sendo-lhe vedada a representação judicial e a consultoria jurídica de
# entidades públicas. § 1º - A legitimação do Ministério Público para as ações civis previstas neste artigo  não impede a de terceiros, nas mesmas hipóteses, segundo o disposto nesta
# Constituição e na lei.
# -----------------------------------------------------------------
# Segmento_id: 2105. Score: 13.496881246566772
# Title: Constituição Federal
# Contents: [Constituição Federal]: (Incluído pela Emenda Constitucional nº 132, de 2023)
#   Art. 156-B.  Os Estados, o Distrito Federal e os Municípios exercerão de forma integrada, exclusivamente por meio do Comitê Gestor do Imposto sobre Bens e
# Serviços, nos termos e limites estabelecidos nesta Constituição e em lei complementar , as seguintes competências administrativas relativas ao imposto de que trata o art. 156-
# A:     (Incluído pela Emenda Constitucional nº 132, de 2023)
# I - editar regulamento único e uniformizar a interpretação e a aplicação da legislação do imposto;     (Incluído pela Emenda Constitucional nº 132, de 2023)
# II - arrecadar o imposto, efetuar as comp ensações e distribuir o produto da arrecadação entre Estados, Distrito Federal e Municípios;     (Incluído pela Emenda
# Constitucional nº 132, de 2023)
# III - decidir o contencioso administrativo. (Incluído pela Emenda Constitucional nº 132, de 2023)
# § 1º O Com itê Gestor do Imposto sobre Bens e Serviços, entidade pública sob regime especial, terá independência técnica, administrativa, orçamentária e financeira. (Incluído pela Emenda Constitucional nº 132, de 2023)
# § 2º Na forma da lei complementar:     (Incluído pela Emenda Constitucional nº 132, de 2023)
# I - os Estados, o Distri to Federal e os Municípios serão representados, de forma paritária, na instância máxima de deliberação do Comitê Gestor do Imposto sobre Bens e
# Serviços;     (Incluído pela Emenda Constitucional nº 132, de 2023)
# II - será assegurada a alternância na presid ência do Comitê Gestor entre o conjunto dos Estados e o Distrito Federal e o conjunto dos Municípios e o Distrito Federal;
# (Incluído pela Emenda Constitucional nº 132, de 2023)
# III - o Comitê Gestor será financiado por percentual do produto da arrecadação do imposto destinado a cada ente federativo;     (Incluído pela Emenda Constitucional nº
# 132, de 2023)
# IV - o controle externo do Comitê Gestor será exercido pelos Estados, pelo Distrito Federal e pelos Municípios;     (Incluído pela Emenda Constitucional nº 132, de 2023)
# V - a fiscalização, o lançamento, a cobrança, a representação administrativa e a representação judicial relativos ao imposto serão realizados, no âmbito de suas respectivas
# competências, pelas administrações tributá rias e procuradorias dos Estados, do Distrito Federal e dos Municípios, que poderão definir hipóteses de delegação ou de
# compartilhamento de competências, cabendo ao Comitê Gestor a coordenação dessas atividades administrativas com vistas à integração entre os entes federativos;     (Incluído
# pela Emenda Constitucional nº 132, de 2023)07/06/2024, 11:39 Constituição
# www.planalto.gov.br/ccivil_03/constituicao/constituicao.htm 117/226
# VI - as competências exclusivas das carreiras da administração tributária e das procuradorias dos Estados, do Distrito Federal e dos Municípios serão exercidas, no Comitê
# Gestor e na representação deste, por servidores das referidas carreiras;     (Incluído pela Emenda Constitucional nº 132, de 2023)
# VII - serão estabelecidas a estrutura e a gestão do Comitê Gestor , cabendo ao regimento interno dispor sobre sua organização e funcionamento.
# -----------------------------------------------------------------
# Segmento_id: 227. Score: 13.4347163438797
# Title: Constituição Estadual SP
# Contents: [Constituição Estadual SP]: NR)
# - "Caput" com redação dada pela Emenda Constitucional n° 19, de 14/04/2004. Parágrafo único - As atividades de representação judicial, consultoria e assessoramento jurídico das universidades públicas estaduais poderão
# ser realizadas ou supervisionadas, total ou parcialmente, pela Procuradoria Geral do Estado, na forma a ser estabelecida em convênio. ( NR)
# - Parágrafo único acrescentado pela Emenda Constitucional n° 19, de 14/04/2004.
# -----------------------------------------------------------------
# Segmento_id: 75. Score: 13.383461236953735
# Title: Constituição Estadual SP
# Contents: [Constituição Estadual SP]: SEÇÃO V
# Da Procuradoria da Assembleia Legislativa
# Artigo 30 - À Procuradoria da Assembleia Legislativa compete exercer a represe ntação judicial, a consultoria e o assessoramento técnico-
# jurídico do Poder Legislativo. Parágrafo único - Lei de iniciativa da Mesa da Assem bleia Legislativa organizará a Procuradoria da Assembleia Legislativa, observados os
# princípios e regras pertinentes da Constituição Federal e desta Constituição, disciplinará sua competência e disporá sobre o ingresso na classe
# inicial, mediante concurso público de provas e títulos. SEÇÃO VI
# Do T ribunal de Contas
# Artigo 31 - O Tribun al de Contas do Estado, integrado por sete Conselheiros, tem sede na Capital do Estado, quadro próprio de pessoal e
# jurisdição em todo o território estadual, exercendo, no que couber , as atribuições previstas no artigo 96 da Constituição Federal.
# -----------------------------------------------------------------
# Segmento_id: 74. Score: 13.213885068893433
# Title: Constituição Estadual SP
# Contents: [Constituição Estadual SP]: Artigo 29 - A matéria constante de projeto de lei rejeitado somente poderá ser renovada, na mesma sessão legislativa, mediante proposta da
# maioria absoluta dos membros da Assembleia Legislativa. ( NR)
# - Expressão "Ressalvados os projetos de iniciativa exclusiva", anteriormente constante deste artigo, declarada inconstitucional, em controle concentrado, pelo Supremo
# Tribunal Federal nos autos da ADI n° 1546. SEÇÃO V
# Da Procuradoria da Assembleia Legislativa
# Artigo 30 - À Procuradoria da Assembleia Legislativa compete exercer a represe ntação judicial, a consultoria e o assessoramento técnico-
# jurídico do Poder Legislativo.
# -----------------------------------------------------------------
# Segmento_id: 2531. Score: 13.026296377182007
# Title: Constituição Federal
# Contents: [Constituição Federal]: Para efeito de promoção por antigüidade, o tempo de serviço desses juízes será computado a partir do dia de sua posse. Art. 29. Enquanto não aprovadas as leis complementares relativas ao Ministério Público e à Advocacia-Geral da União, o Ministério Público Federal, a Procuradoria-Geral
# da Fazenda Nacional, as Consultorias Jurídicas dos Ministérios, as Procuradorias e Depa rtamentos Jurídicos de autarquias federais com representação própria e os membros das
# Procuradorias das Universidades fundacionais públicas continuarão a exercer suas atividades na área das respectivas atribuições.
# -----------------------------------------------------------------
# Segmento_id: 3343. Score: 12.626301646232605
# Title: Resolução GR-018/2018
# Contents: [Resolução GR-018/2018]: Resolução GR-018/2018, de 25/01/2018
#
#
#
#
#
#
#
#
#
#                      Reitor: Marcelo Knobel
#
#
#
#
#
#
#
#
#
#
#
#                                              Altera a  Resolução GR-034/2017 , que instituiu a Diretoria Executiva de Relações Internacionais e a Diretoria Executiva de Administração; a  Resolução GR-017/2010 , que delega competência aos servidores da Diretoria Geral da Administração; e a  Portaria GR-248/1998 , que regulamenta a forma de aplicação das Sanções Administrativas, previstas na Lei Federal nº 8.666/93, nas hipóteses de recusa injustificada do instrumento de contrato, inexecução total ou parcial verificados nos ajustes de compras, serviços e obras celebrados com a UNICAMP. O Reitor da Universidade Estadual de Campinas, no uso de suas atribuições legais e considerando a necessidade de organização administrativa, RESOLVE: Artigo 1º  - As alíneas “d” e “j” do inciso I do artigo 1º da  Resolução GR-017/2010  passam a vigorar com a seguinte redação: “d) conhecer e decidir recurso administrativo interposto contra atos do Pregoeiro e da Comissão Julgadora de Proposta e/ou Habilitação e, no caso de não reconsideração da decisão, remetê-lo devidamente informado ao Diretor Executivo de Administração, por intermédio da Procuradoria Geral, para decisão final;. (...) j) conhecer e decidir recurso interposto contra atos sancionatórios previstos nas alíneas “g” e “h” deste inciso, remetendo-o ao Diretor Executivo de Administração, por intermédio da Procuradoria Geral, no caso de não ocorrer a reconsideração da decisão recorrida;” Artigo 2º  - Os artigos 14 e 15 da  Portaria GR-248/1998  passam a vigorar com a seguinte redação: Artigo 14 – Da decisão da aplicação das sanções estabelecidas nos itens I e II do artigo 6º desta Portaria, caberá recurso dirigido ao Diretor Executivo de Administração através dos Diretores das Unidades Universitárias e Órgãos Administrativos.
# -----------------------------------------------------------------
# Segmento_id: 2106. Score: 12.333449959754944
# Title: Constituição Federal
# Contents: [Constituição Federal]: (Incluído pela Emenda Constitucional nº 132, de 2023)
# § 2º Na forma da lei complementar:     (Incluído pela Emenda Constitucional nº 132, de 2023)
# I - os Estados, o Distri to Federal e os Municípios serão representados, de forma paritária, na instância máxima de deliberação do Comitê Gestor do Imposto sobre Bens e
# Serviços;     (Incluído pela Emenda Constitucional nº 132, de 2023)
# II - será assegurada a alternância na presid ência do Comitê Gestor entre o conjunto dos Estados e o Distrito Federal e o conjunto dos Municípios e o Distrito Federal;
# (Incluído pela Emenda Constitucional nº 132, de 2023)
# III - o Comitê Gestor será financiado por percentual do produto da arrecadação do imposto destinado a cada ente federativo;     (Incluído pela Emenda Constitucional nº
# 132, de 2023)
# IV - o controle externo do Comitê Gestor será exercido pelos Estados, pelo Distrito Federal e pelos Municípios;     (Incluído pela Emenda Constitucional nº 132, de 2023)
# V - a fiscalização, o lançamento, a cobrança, a representação administrativa e a representação judicial relativos ao imposto serão realizados, no âmbito de suas respectivas
# competências, pelas administrações tributá rias e procuradorias dos Estados, do Distrito Federal e dos Municípios, que poderão definir hipóteses de delegação ou de
# compartilhamento de competências, cabendo ao Comitê Gestor a coordenação dessas atividades administrativas com vistas à integração entre os entes federativos;     (Incluído
# pela Emenda Constitucional nº 132, de 2023)07/06/2024, 11:39 Constituição
# www.planalto.gov.br/ccivil_03/constituicao/constituicao.htm 117/226
# VI - as competências exclusivas das carreiras da administração tributária e das procuradorias dos Estados, do Distrito Federal e dos Municípios serão exercidas, no Comitê
# Gestor e na representação deste, por servidores das referidas carreiras;     (Incluído pela Emenda Constitucional nº 132, de 2023)
# VII - serão estabelecidas a estrutura e a gestão do Comitê Gestor , cabendo ao regimento interno dispor sobre sua organização e funcionamento. (Incluído pela Emenda
# Constitucional nº 132, de 2023)
# § 3º A participação dos entes federativos na instância máxima de deliberação do Comitê Gestor do Imposto sobre Bens e Serviços observará a seguinte composição:
# (Incluído pela Emenda Constitucional nº 132, de 2023)
# I - 27 (vinte e sete) membros, representando cada Estado e o Distrito Federal;    (Incluído pela Emenda Constitucional nº 132, de 2023)
# II - 27 (vinte e sete) membros, representando o conjunto dos Municípios e do Distrito Federal, que serão eleitos nos seguintes termos:     (Incluído pela Emenda
# Constitucional nº 132, de 2023)
# a) 14 (quatorze) representantes, com base nos votos de cada Município, com valor igual para todos; e     (Incluído pela Emenda Constitucional nº 132, de 2023)
# b) 13 (treze) representantes, com base nos votos de cada Município ponderados pelas respectivas populações. (Incluído pela Emenda Constitucional nº 132, de 2023)
# § 4º As deliberações no âmbito do Comitê Gestor do Imposto sobre Bens e Serviços serão consideradas aprovadas se obtiverem, cumulativamente, os votos:     (Incluído
# pela Emenda Constitucional nº 132, de 2023)
# I - em relação ao conjunto dos Estados e do Distrito Federal:     (Incluído pela Emenda Constitucional nº 132, de 2023)
# a) da maioria absoluta de seus representantes; e     (Incluído pela Emenda Constitucional nº 132, de 2023)
# b) de repre sentantes dos Estados e do Distrito Federal que correspondam a mais de 50% (cinquenta por cento) da população do País; e      (Incluído pela Emenda
# Constitucional nº 132, de 2023)
# II - em relação ao conjunto dos Municípios e do Distrito Federal, da maioria absoluta de seus representantes.
# -----------------------------------------------------------------
# Segmento_id: 2532. Score: 12.33043122291565
# Title: Constituição Federal
# Contents: [Constituição Federal]: Enquanto não aprovadas as leis complementares relativas ao Ministério Público e à Advocacia-Geral da União, o Ministério Público Federal, a Procuradoria-Geral
# da Fazenda Nacional, as Consultorias Jurídicas dos Ministérios, as Procuradorias e Depa rtamentos Jurídicos de autarquias federais com representação própria e os membros das
# Procuradorias das Universidades fundacionais públicas continuarão a exercer suas atividades na área das respectivas atribuições. § 1º  O Presidente da República, no prazo  de cento e vinte dias, encaminhará ao Congresso Nacional projeto de lei complementar dispondo sobre a organização e o
# funcionamento da Advocacia-Geral da União. § 2º  Aos atuais Procu radores da República, nos termos da lei complementar , será facult ada a opção, de forma irretratável, entre as carreiras do Ministério Público Federal
# e da Advocacia-Geral da União.
# -----------------------------------------------------------------
# Segmento_id: 1297. Score: 12.318874716758728
# Title: Deliberação CONSU-A-016/2022
# Contents: [Deliberação CONSU-A-016/2022]: 2º  – Memorando de entendimento ou carta de intenção não vinculativo e que não crie obrigações para a Universidade poderá ser assinado pelo Reitor, mediante análise jurídica prévia da Procuradoria Geral, sem necessidade de submissão à Cacc. § 3º  – O processo aberto pela Inova para a tramitação de contrato de ajuste de Propriedade Intelectual previsto no inciso I, alínea “g” deste artigo deverá ser encaminhado às Unidades ou Órgãos aos quais os servidores da equipe executora sejam vinculados, para ciência de seus dirigentes antes do envio à Procuradoria Geral. § 4º  – O simples termo de transferência de material (TTM ou MTA) que utilizar o modelo padrão aprovado pela Resolução CGEN nº 27, de 25 de agosto de 2021, fica dispensado da tramitação prevista na presente Deliberação, podendo ser submetido diretamente ao Pró-Reitor de Pesquisa para assinatura.
# -----------------------------------------------------------------

# %%
artigos_segmentados
# Out:
# [{'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: A\nFicha informativa\nTexto com alterações\nCONSTITUIÇÃO EST ADUAL, DE 05 DE OUTUBRO DE 1989\n(Última atualização: Emenda Constitucional n° 53, de 19/12/2023)\nPREÂMBULO\nO Povo Paulista, invocando a proteção de Deus, e inspirado nos princíp ios constitucionais da República e no ideal de a todos assegurar justiça\ne bem-estar , decreta e promulga, por seus representantes, a CONSTITUIÇÃO DO EST ADO DE SÃO P AULO. TÍTULO I\nDos Fundamentos do Estado\nArtigo 1° - O Estado de São Paulo, integrant e da República Federativa do Brasil, exerce as competências que não lhe são vedadas pela\nConstituição Federal. Artigo 2° - A lei estabelecerá procedimentos judiciários abreviados e de custos reduzidos para as ações cujo objeto principal seja a salvaguarda\ndos direitos e liberdades fundamentais.',
#   'segment': 'A\nFicha informativa\nTexto com alterações\nCONSTITUIÇÃO EST ADUAL, DE 05 DE OUTUBRO DE 1989\n(Última atualização: Emenda Constitucional n° 53, de 19/12/2023)\nPREÂMBULO\nO Povo Paulista, invocando a proteção de Deus, e inspirado nos princíp ios constitucionais da República e no ideal de a todos assegurar justiça\ne bem-estar , decreta e promulga, por seus representantes, a CONSTITUIÇÃO DO EST ADO DE SÃO P AULO. TÍTULO I\nDos Fundamentos do Estado\nArtigo 1° - O Estado de São Paulo, integrant e da República Federativa do Brasil, exerce as competências que não lhe são vedadas pela\nConstituição Federal. Artigo 2° - A lei estabelecerá procedimentos judiciários abreviados e de custos reduzidos para as ações cujo objeto principal seja a salvaguarda\ndos direitos e liberdades fundamentais.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: Artigo 2° - A lei estabelecerá procedimentos judiciários abreviados e de custos reduzidos para as ações cujo objeto principal seja a salvaguarda\ndos direitos e liberdades fundamentais. Artigo 3° -  O Estado prestará assistência jurídica integral e gratuita aos que declararem insuficiência de recursos. Artigo 4° - Nos procedimentos administrativos , qualquer que seja o objeto, observar-se-ão, entre outros requisitos de validade, a igualdade\nentre os administrados e o devido processo legal, especialmente quanto à exigência da publicidade, do contraditório, da ampla defesa e do\ndespacho ou decisão motivados.',
#   'segment': 'Artigo 2° - A lei estabelecerá procedimentos judiciários abreviados e de custos reduzidos para as ações cujo objeto principal seja a salvaguarda\ndos direitos e liberdades fundamentais. Artigo 3° -  O Estado prestará assistência jurídica integral e gratuita aos que declararem insuficiência de recursos. Artigo 4° - Nos procedimentos administrativos , qualquer que seja o objeto, observar-se-ão, entre outros requisitos de validade, a igualdade\nentre os administrados e o devido processo legal, especialmente quanto à exigência da publicidade, do contraditório, da ampla defesa e do\ndespacho ou decisão motivados.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: Artigo 4° - Nos procedimentos administrativos , qualquer que seja o objeto, observar-se-ão, entre outros requisitos de validade, a igualdade\nentre os administrados e o devido processo legal, especialmente quanto à exigência da publicidade, do contraditório, da ampla defesa e do\ndespacho ou decisão motivados. TÍTULO II\nDa Organização dos Poderes\nCAPÍTULO I\nDisposições Preliminares\nArtigo 5° -  São Poderes do Estado, independentes e harmônicos entre si, o Legislativo, o Executivo e o Judiciário. §1° -  É vedado a qualquer dos Poderes delegar atribuições.07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 1/84\n§2° -  O cidadão, investido na função de um dos Poderes, não poderá exercer a de outro, salvo as exceções previstas nesta Constituição.',
#   'segment': 'Artigo 4° - Nos procedimentos administrativos , qualquer que seja o objeto, observar-se-ão, entre outros requisitos de validade, a igualdade\nentre os administrados e o devido processo legal, especialmente quanto à exigência da publicidade, do contraditório, da ampla defesa e do\ndespacho ou decisão motivados. TÍTULO II\nDa Organização dos Poderes\nCAPÍTULO I\nDisposições Preliminares\nArtigo 5° -  São Poderes do Estado, independentes e harmônicos entre si, o Legislativo, o Executivo e o Judiciário. §1° -  É vedado a qualquer dos Poderes delegar atribuições.07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 1/84\n§2° -  O cidadão, investido na função de um dos Poderes, não poderá exercer a de outro, salvo as exceções previstas nesta Constituição.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §1° -  É vedado a qualquer dos Poderes delegar atribuições.07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 1/84\n§2° -  O cidadão, investido na função de um dos Poderes, não poderá exercer a de outro, salvo as exceções previstas nesta Constituição. Artigo 6° -  O Município de São Paulo é a Capital do Estado. Artigo 7° - São símbolos do Estado a bandeira, o brasão de armas e o hino.',
#   'segment': '§1° -  É vedado a qualquer dos Poderes delegar atribuições.07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 1/84\n§2° -  O cidadão, investido na função de um dos Poderes, não poderá exercer a de outro, salvo as exceções previstas nesta Constituição. Artigo 6° -  O Município de São Paulo é a Capital do Estado. Artigo 7° - São símbolos do Estado a bandeira, o brasão de armas e o hino.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: Artigo 7° - São símbolos do Estado a bandeira, o brasão de armas e o hino. Artigo 8° - Além dos indicados no artigo 26 da Constituição Federal, incluem-se entre os bens do Estado os terrenos reservados às margens\ndos rios e lagos do seu domínio. CAPÍTULO II\nDo Poder Legislativo\nSEÇÃO I\nDa Organização do Poder Legislativo\nArtigo 9° - O Poder  Legislati vo é exercido pela Assembleia Legislativa, constituída de Deputados, eleitos e investidos na forma da legislação\nfederal, para uma legislatura de quatro anos.',
#   'segment': 'Artigo 7° - São símbolos do Estado a bandeira, o brasão de armas e o hino. Artigo 8° - Além dos indicados no artigo 26 da Constituição Federal, incluem-se entre os bens do Estado os terrenos reservados às margens\ndos rios e lagos do seu domínio. CAPÍTULO II\nDo Poder Legislativo\nSEÇÃO I\nDa Organização do Poder Legislativo\nArtigo 9° - O Poder  Legislati vo é exercido pela Assembleia Legislativa, constituída de Deputados, eleitos e investidos na forma da legislação\nfederal, para uma legislatura de quatro anos.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: CAPÍTULO II\nDo Poder Legislativo\nSEÇÃO I\nDa Organização do Poder Legislativo\nArtigo 9° - O Poder  Legislati vo é exercido pela Assembleia Legislativa, constituída de Deputados, eleitos e investidos na forma da legislação\nfederal, para uma legislatura de quatro anos. §1° - A Assembleia Legislativa reunir-se-á, em sessão legislativa anual, independentemente de convocação, de 1° de fevereiro a 30 de junho e\nde 1° de agosto a 15 de dezembro. § 2° - No primeiro ano da legislatura, a Assembleia Legislativa reunir-se -á, da mesma forma, em sessões preparatórias, a partir de 1° de\nfevereiro, para a posse de seus membros e eleição da Mesa. (',
#   'segment': 'CAPÍTULO II\nDo Poder Legislativo\nSEÇÃO I\nDa Organização do Poder Legislativo\nArtigo 9° - O Poder  Legislati vo é exercido pela Assembleia Legislativa, constituída de Deputados, eleitos e investidos na forma da legislação\nfederal, para uma legislatura de quatro anos. §1° - A Assembleia Legislativa reunir-se-á, em sessão legislativa anual, independentemente de convocação, de 1° de fevereiro a 30 de junho e\nde 1° de agosto a 15 de dezembro. § 2° - No primeiro ano da legislatura, a Assembleia Legislativa reunir-se -á, da mesma forma, em sessões preparatórias, a partir de 1° de\nfevereiro, para a posse de seus membros e eleição da Mesa. ('},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: § 2° - No primeiro ano da legislatura, a Assembleia Legislativa reunir-se -á, da mesma forma, em sessões preparatórias, a partir de 1° de\nfevereiro, para a posse de seus membros e eleição da Mesa. ( NR)\n- § 2° com redação dada pela Emenda Constitucional n° 47, de 14/03/2019. §3° - As reuniõ es marc adas para as datas fixadas no § 1° serão transferidas para o primeiro dia útil subsequente, quando recaírem em sábado,\ndomingo ou feriado.',
#   'segment': '§ 2° - No primeiro ano da legislatura, a Assembleia Legislativa reunir-se -á, da mesma forma, em sessões preparatórias, a partir de 1° de\nfevereiro, para a posse de seus membros e eleição da Mesa. ( NR)\n- § 2° com redação dada pela Emenda Constitucional n° 47, de 14/03/2019. §3° - As reuniõ es marc adas para as datas fixadas no § 1° serão transferidas para o primeiro dia útil subsequente, quando recaírem em sábado,\ndomingo ou feriado.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §3° - As reuniõ es marc adas para as datas fixadas no § 1° serão transferidas para o primeiro dia útil subsequente, quando recaírem em sábado,\ndomingo ou feriado. §4° - A sessão  legislativa não será interrompida sem aprovação do projeto de lei de diretrizes orçamentárias e sem deliberação sobre o projeto\nde lei do orçamento e sobre as contas prestadas pelo Governador , referentes ao exercício anterior . ( NR)\n- § 4° com redação dada pela Emenda Constitucional n° 5, de 18/12/1998.',
#   'segment': '§3° - As reuniõ es marc adas para as datas fixadas no § 1° serão transferidas para o primeiro dia útil subsequente, quando recaírem em sábado,\ndomingo ou feriado. §4° - A sessão  legislativa não será interrompida sem aprovação do projeto de lei de diretrizes orçamentárias e sem deliberação sobre o projeto\nde lei do orçamento e sobre as contas prestadas pelo Governador , referentes ao exercício anterior . ( NR)\n- § 4° com redação dada pela Emenda Constitucional n° 5, de 18/12/1998.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: NR)\n- § 4° com redação dada pela Emenda Constitucional n° 5, de 18/12/1998. §5° - A convocação extraordinária da Assembleia Legislativa far-se-á:\n1 - pelo Presidente, nos seguintes casos:\na) decretação de estado de sítio ou de estado de defesa que atinja todo ou parte do território estadual;\nb) intervenção no Estado ou em Município;\nc) recebimento dos autos de prisão de Deputado, na hipótese de crime inafiançável. 2 - pela maioria absoluta dos membros da Assembleia Legislativa ou pelo Governador , em caso de urgência ou interesse público relevante.',
#   'segment': 'NR)\n- § 4° com redação dada pela Emenda Constitucional n° 5, de 18/12/1998. §5° - A convocação extraordinária da Assembleia Legislativa far-se-á:\n1 - pelo Presidente, nos seguintes casos:\na) decretação de estado de sítio ou de estado de defesa que atinja todo ou parte do território estadual;\nb) intervenção no Estado ou em Município;\nc) recebimento dos autos de prisão de Deputado, na hipótese de crime inafiançável. 2 - pela maioria absoluta dos membros da Assembleia Legislativa ou pelo Governador , em caso de urgência ou interesse público relevante.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: 2 - pela maioria absoluta dos membros da Assembleia Legislativa ou pelo Governador , em caso de urgência ou interesse público relevante. §6° - Na sessão legislativa extraordinária , a Assembleia Legislativa somente deliberará sobre a matéria para a qual foi convocada, vedado o\npagamento de parcela indenizatória de valor superior ao subsídio mensal. ( NR)\n- § 6° com redação dada pela Emenda Constitucional n° 21, de 14/02/2006.',
#   'segment': '2 - pela maioria absoluta dos membros da Assembleia Legislativa ou pelo Governador , em caso de urgência ou interesse público relevante. §6° - Na sessão legislativa extraordinária , a Assembleia Legislativa somente deliberará sobre a matéria para a qual foi convocada, vedado o\npagamento de parcela indenizatória de valor superior ao subsídio mensal. ( NR)\n- § 6° com redação dada pela Emenda Constitucional n° 21, de 14/02/2006.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: NR)\n- § 6° com redação dada pela Emenda Constitucional n° 21, de 14/02/2006. Artigo 10 - A Assembleia Legislativa funcionar á em sessões públicas, presente, nas sessões deliberativas, pelo menos um quarto de seus\nmembros e, nas sessões exclusivamente de debates, pelo menos um oitavo de seus membros. ( NR)\n- "Caput" com redação dada pela Emenda Constitucional n° 36, de 17/05/2012.',
#   'segment': 'NR)\n- § 6° com redação dada pela Emenda Constitucional n° 21, de 14/02/2006. Artigo 10 - A Assembleia Legislativa funcionar á em sessões públicas, presente, nas sessões deliberativas, pelo menos um quarto de seus\nmembros e, nas sessões exclusivamente de debates, pelo menos um oitavo de seus membros. ( NR)\n- "Caput" com redação dada pela Emenda Constitucional n° 36, de 17/05/2012.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: NR)\n- "Caput" com redação dada pela Emenda Constitucional n° 36, de 17/05/2012. §1° - Salvo disposição constitucional em contrário, as deliberações da Assembleia Legislativa e de suas Comissões serão tomadas por maioria\nde votos, presente a maioria absoluta de seus membros. §2° -  O voto será público. (',
#   'segment': 'NR)\n- "Caput" com redação dada pela Emenda Constitucional n° 36, de 17/05/2012. §1° - Salvo disposição constitucional em contrário, as deliberações da Assembleia Legislativa e de suas Comissões serão tomadas por maioria\nde votos, presente a maioria absoluta de seus membros. §2° -  O voto será público. ('},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §2° -  O voto será público. ( NR)07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 2/84\n- § 2° com redação dada pela Emenda Constitucional n° 12, de 28/06/2001. 1 - Revogado.',
#   'segment': '§2° -  O voto será público. ( NR)07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 2/84\n- § 2° com redação dada pela Emenda Constitucional n° 12, de 28/06/2001. 1 - Revogado.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: 1 - Revogado. - Item 1 revogado pela Emenda Constitucional n° 12, de 28/06/2001. 2 - Revogado.',
#   'segment': '1 - Revogado. - Item 1 revogado pela Emenda Constitucional n° 12, de 28/06/2001. 2 - Revogado.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: 2 - Revogado. - Item 2 revogado pela Emenda Constitucional n° 12, de 28/06/2001. 3 - Revogado.',
#   'segment': '2 - Revogado. - Item 2 revogado pela Emenda Constitucional n° 12, de 28/06/2001. 3 - Revogado.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: 3 - Revogado. - Item 3 revogado pela Emenda Constitucional n° 12, de 28/06/2001. 4 - Revogado.',
#   'segment': '3 - Revogado. - Item 3 revogado pela Emenda Constitucional n° 12, de 28/06/2001. 4 - Revogado.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: 4 - Revogado. - Item 4 revogado pela Emenda Constitucional n° 12, de 28/06/2001. 5 - Revogado.',
#   'segment': '4 - Revogado. - Item 4 revogado pela Emenda Constitucional n° 12, de 28/06/2001. 5 - Revogado.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: 5 - Revogado. - Item 5 revogado pela Emenda Constitucional n° 12, de 28/06/2001. Artigo 1 1 - Os membros da Mesa e seus substitutos serão eleitos para um mandato de dois anos.',
#   'segment': '5 - Revogado. - Item 5 revogado pela Emenda Constitucional n° 12, de 28/06/2001. Artigo 1 1 - Os membros da Mesa e seus substitutos serão eleitos para um mandato de dois anos.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: Artigo 1 1 - Os membros da Mesa e seus substitutos serão eleitos para um mandato de dois anos. §1° - A eleição far-se-á, em primeiro escrutínio, pela maioria absoluta da Assembleia Legislativa. §2° -  É vedada a recondução para o mesmo cargo na eleição imediatamente subsequente.',
#   'segment': 'Artigo 1 1 - Os membros da Mesa e seus substitutos serão eleitos para um mandato de dois anos. §1° - A eleição far-se-á, em primeiro escrutínio, pela maioria absoluta da Assembleia Legislativa. §2° -  É vedada a recondução para o mesmo cargo na eleição imediatamente subsequente.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §2° -  É vedada a recondução para o mesmo cargo na eleição imediatamente subsequente. Artigo 12 - Na constituição da Mesa e das Comissões assegurar-se-á, tanto quanto possível, a representação proporcional dos partidos\npolíticos com assento na Assembleia Legislativa. Artigo 13 - A Assem bleia Legislativa terá Com issões permanentes e temporárias, na forma e com as atribuições previstas no Regimento\nInterno.',
#   'segment': '§2° -  É vedada a recondução para o mesmo cargo na eleição imediatamente subsequente. Artigo 12 - Na constituição da Mesa e das Comissões assegurar-se-á, tanto quanto possível, a representação proporcional dos partidos\npolíticos com assento na Assembleia Legislativa. Artigo 13 - A Assem bleia Legislativa terá Com issões permanentes e temporárias, na forma e com as atribuições previstas no Regimento\nInterno.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: Artigo 13 - A Assem bleia Legislativa terá Com issões permanentes e temporárias, na forma e com as atribuições previstas no Regimento\nInterno. §1° -  Às comissões, em razão da matéria de sua competência, cabe:\n1 - discutir e votar projetos de lei que dispensarem, na forma do Regimento Interno, a competência do Plenário, salvo se houver , para decisão\ndeste, requerimento de um décimo dos membros da Assembleia Legislativa;\n2 - convoca r Secretário de Estado, sem prejuízo do disposto no artigo 52-A, para prestar pessoalmente, no prazo de 30 (trinta) dias,\ninformações sobre assunto previamente determinado, importando crime de responsabilidade a ausência sem justificação adequada; (NR)\n- Item 2 com redação dada pela Emenda Constitucional n° 27, de 15/06/2009. 3 - convoca r dirigent es de autarquias, empresas públicas, sociedades de economia mista e fundações instituídas ou mantidas pelo Poder\nPúblico, para prestar informações sobre assuntos de área de sua competência, previamente determinados, no prazo de trinta dias, sujeitando-\nse, pelo não comparecimento sem justificação adequada, às penas da lei;\n4 - convocar o Procurador-Geral de Justiça, o Procurador-Geral do Estado e o Defensor Público-Geral, para prestar informações a respeito de\nassuntos previamente fixados, relacionados com a respectiva área;\n5 - acompanhar a execução orçamentária;\n6 - realizar audiências públicas dentro ou fora da sede do Poder Legislativo;\n7 - receber petições, reclamações, representações ou queixas de qualqu er pessoa contra atos ou omissões das autoridades ou entidades\npúblicas;\n8 - velar pela completa adequação dos atos do Poder Executivo que regulamentem dispositivos legais;\n9 - tomar o depoimento de autoridade e solicitar o de cidadão;\n10 - fiscalizar e apreciar programas de obras, planos estaduais, regionais e setoriais de desenvolvimento e, sobre eles, emitir parecer;\n11 - convocar representantes de empresa resultante de sociedade desestat izada e representantes de empresa prestadora de serviço público\nconcedido ou permitido, para prestar informações sobre assuntos de sua área de competência, previamente determinados, no prazo de 30\n(trinta) dias, sujeitando-se, pelo não comparecimento sem adequada justificação, às penas da lei. (',
#   'segment': 'Artigo 13 - A Assem bleia Legislativa terá Com issões permanentes e temporárias, na forma e com as atribuições previstas no Regimento\nInterno. §1° -  Às comissões, em razão da matéria de sua competência, cabe:\n1 - discutir e votar projetos de lei que dispensarem, na forma do Regimento Interno, a competência do Plenário, salvo se houver , para decisão\ndeste, requerimento de um décimo dos membros da Assembleia Legislativa;\n2 - convoca r Secretário de Estado, sem prejuízo do disposto no artigo 52-A, para prestar pessoalmente, no prazo de 30 (trinta) dias,\ninformações sobre assunto previamente determinado, importando crime de responsabilidade a ausência sem justificação adequada; (NR)\n- Item 2 com redação dada pela Emenda Constitucional n° 27, de 15/06/2009. 3 - convoca r dirigent es de autarquias, empresas públicas, sociedades de economia mista e fundações instituídas ou mantidas pelo Poder\nPúblico, para prestar informações sobre assuntos de área de sua competência, previamente determinados, no prazo de trinta dias, sujeitando-\nse, pelo não comparecimento sem justificação adequada, às penas da lei;\n4 - convocar o Procurador-Geral de Justiça, o Procurador-Geral do Estado e o Defensor Público-Geral, para prestar informações a respeito de\nassuntos previamente fixados, relacionados com a respectiva área;\n5 - acompanhar a execução orçamentária;\n6 - realizar audiências públicas dentro ou fora da sede do Poder Legislativo;\n7 - receber petições, reclamações, representações ou queixas de qualqu er pessoa contra atos ou omissões das autoridades ou entidades\npúblicas;\n8 - velar pela completa adequação dos atos do Poder Executivo que regulamentem dispositivos legais;\n9 - tomar o depoimento de autoridade e solicitar o de cidadão;\n10 - fiscalizar e apreciar programas de obras, planos estaduais, regionais e setoriais de desenvolvimento e, sobre eles, emitir parecer;\n11 - convocar representantes de empresa resultante de sociedade desestat izada e representantes de empresa prestadora de serviço público\nconcedido ou permitido, para prestar informações sobre assuntos de sua área de competência, previamente determinados, no prazo de 30\n(trinta) dias, sujeitando-se, pelo não comparecimento sem adequada justificação, às penas da lei. ('},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: 3 - convoca r dirigent es de autarquias, empresas públicas, sociedades de economia mista e fundações instituídas ou mantidas pelo Poder\nPúblico, para prestar informações sobre assuntos de área de sua competência, previamente determinados, no prazo de trinta dias, sujeitando-\nse, pelo não comparecimento sem justificação adequada, às penas da lei;\n4 - convocar o Procurador-Geral de Justiça, o Procurador-Geral do Estado e o Defensor Público-Geral, para prestar informações a respeito de\nassuntos previamente fixados, relacionados com a respectiva área;\n5 - acompanhar a execução orçamentária;\n6 - realizar audiências públicas dentro ou fora da sede do Poder Legislativo;\n7 - receber petições, reclamações, representações ou queixas de qualqu er pessoa contra atos ou omissões das autoridades ou entidades\npúblicas;\n8 - velar pela completa adequação dos atos do Poder Executivo que regulamentem dispositivos legais;\n9 - tomar o depoimento de autoridade e solicitar o de cidadão;\n10 - fiscalizar e apreciar programas de obras, planos estaduais, regionais e setoriais de desenvolvimento e, sobre eles, emitir parecer;\n11 - convocar representantes de empresa resultante de sociedade desestat izada e representantes de empresa prestadora de serviço público\nconcedido ou permitido, para prestar informações sobre assuntos de sua área de competência, previamente determinados, no prazo de 30\n(trinta) dias, sujeitando-se, pelo não comparecimento sem adequada justificação, às penas da lei. ( NR)07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 3/84\n- Item 11 acrescentado pela Emenda Constitucional n° 10, de 20/02/2001. §2° - As comissões parlamentares de inquérito, que terão poderes de investigação próprios das autoridades judiciais, além de outros previstos\nno Regim ento Interno, serão criadas mediante requerimento de um terço dos membros da Assembleia Legislativa, para apuração de fato\ndeterminado e por prazo certo, sendo suas conclusões, quando for o caso, encaminhadas aos órgãos competentes do Estado para que\npromovam a responsabilidade civil e criminal de quem de direito.',
#   'segment': '3 - convoca r dirigent es de autarquias, empresas públicas, sociedades de economia mista e fundações instituídas ou mantidas pelo Poder\nPúblico, para prestar informações sobre assuntos de área de sua competência, previamente determinados, no prazo de trinta dias, sujeitando-\nse, pelo não comparecimento sem justificação adequada, às penas da lei;\n4 - convocar o Procurador-Geral de Justiça, o Procurador-Geral do Estado e o Defensor Público-Geral, para prestar informações a respeito de\nassuntos previamente fixados, relacionados com a respectiva área;\n5 - acompanhar a execução orçamentária;\n6 - realizar audiências públicas dentro ou fora da sede do Poder Legislativo;\n7 - receber petições, reclamações, representações ou queixas de qualqu er pessoa contra atos ou omissões das autoridades ou entidades\npúblicas;\n8 - velar pela completa adequação dos atos do Poder Executivo que regulamentem dispositivos legais;\n9 - tomar o depoimento de autoridade e solicitar o de cidadão;\n10 - fiscalizar e apreciar programas de obras, planos estaduais, regionais e setoriais de desenvolvimento e, sobre eles, emitir parecer;\n11 - convocar representantes de empresa resultante de sociedade desestat izada e representantes de empresa prestadora de serviço público\nconcedido ou permitido, para prestar informações sobre assuntos de sua área de competência, previamente determinados, no prazo de 30\n(trinta) dias, sujeitando-se, pelo não comparecimento sem adequada justificação, às penas da lei. ( NR)07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 3/84\n- Item 11 acrescentado pela Emenda Constitucional n° 10, de 20/02/2001. §2° - As comissões parlamentares de inquérito, que terão poderes de investigação próprios das autoridades judiciais, além de outros previstos\nno Regim ento Interno, serão criadas mediante requerimento de um terço dos membros da Assembleia Legislativa, para apuração de fato\ndeterminado e por prazo certo, sendo suas conclusões, quando for o caso, encaminhadas aos órgãos competentes do Estado para que\npromovam a responsabilidade civil e criminal de quem de direito.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §2° - As comissões parlamentares de inquérito, que terão poderes de investigação próprios das autoridades judiciais, além de outros previstos\nno Regim ento Interno, serão criadas mediante requerimento de um terço dos membros da Assembleia Legislativa, para apuração de fato\ndeterminado e por prazo certo, sendo suas conclusões, quando for o caso, encaminhadas aos órgãos competentes do Estado para que\npromovam a responsabilidade civil e criminal de quem de direito. §3° - O Regim ento Interno disporá sobre a competência da Comissão representativa da Assembleia Legislativa que funcionará durante o\nrecesso, quando não houver convocação extraordinária. §4° - Aplicam-se ao Conselho de Defesa das Prerrogativas Parlamentares da Assembleia Legislativa as competências previstas nos itens 2, 3, 7\ne 11 do § 1° deste artigo, para apuração de fatos e informações estritamente afetos à inobservância ou infringência das prerrogativas das\nDeputadas e Deputados. (',
#   'segment': '§2° - As comissões parlamentares de inquérito, que terão poderes de investigação próprios das autoridades judiciais, além de outros previstos\nno Regim ento Interno, serão criadas mediante requerimento de um terço dos membros da Assembleia Legislativa, para apuração de fato\ndeterminado e por prazo certo, sendo suas conclusões, quando for o caso, encaminhadas aos órgãos competentes do Estado para que\npromovam a responsabilidade civil e criminal de quem de direito. §3° - O Regim ento Interno disporá sobre a competência da Comissão representativa da Assembleia Legislativa que funcionará durante o\nrecesso, quando não houver convocação extraordinária. §4° - Aplicam-se ao Conselho de Defesa das Prerrogativas Parlamentares da Assembleia Legislativa as competências previstas nos itens 2, 3, 7\ne 11 do § 1° deste artigo, para apuração de fatos e informações estritamente afetos à inobservância ou infringência das prerrogativas das\nDeputadas e Deputados. ('},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §4° - Aplicam-se ao Conselho de Defesa das Prerrogativas Parlamentares da Assembleia Legislativa as competências previstas nos itens 2, 3, 7\ne 11 do § 1° deste artigo, para apuração de fatos e informações estritamente afetos à inobservância ou infringência das prerrogativas das\nDeputadas e Deputados. ( NR)\n- § 4° acrescentado pela Emenda Constitucional n° 42, de 15/10/2015. SEÇÃO II\nDos Deputados\nArtigo 14 -  Os Deputados são invioláveis, civil e penalmente, por quaisquer de suas opiniões, palavras e votos. (',
#   'segment': '§4° - Aplicam-se ao Conselho de Defesa das Prerrogativas Parlamentares da Assembleia Legislativa as competências previstas nos itens 2, 3, 7\ne 11 do § 1° deste artigo, para apuração de fatos e informações estritamente afetos à inobservância ou infringência das prerrogativas das\nDeputadas e Deputados. ( NR)\n- § 4° acrescentado pela Emenda Constitucional n° 42, de 15/10/2015. SEÇÃO II\nDos Deputados\nArtigo 14 -  Os Deputados são invioláveis, civil e penalmente, por quaisquer de suas opiniões, palavras e votos. ('},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: SEÇÃO II\nDos Deputados\nArtigo 14 -  Os Deputados são invioláveis, civil e penalmente, por quaisquer de suas opiniões, palavras e votos. ( NR)\n- "Caput" com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §1° - Os Deputados, desde a expedição do diploma, serão submetidos a julgamento perante o Tribunal de Justiça. (',
#   'segment': 'SEÇÃO II\nDos Deputados\nArtigo 14 -  Os Deputados são invioláveis, civil e penalmente, por quaisquer de suas opiniões, palavras e votos. ( NR)\n- "Caput" com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §1° - Os Deputados, desde a expedição do diploma, serão submetidos a julgamento perante o Tribunal de Justiça. ('},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §1° - Os Deputados, desde a expedição do diploma, serão submetidos a julgamento perante o Tribunal de Justiça. ( NR)\n- § 1° com redação dada pela Emenda Constitucional n° 21, de 14/02/2006. §2° - Desde a expedição do diploma, os membros da Assembleia Legislativa  não poderão ser presos, salvo em flagrante de crime inafiançável.',
#   'segment': '§1° - Os Deputados, desde a expedição do diploma, serão submetidos a julgamento perante o Tribunal de Justiça. ( NR)\n- § 1° com redação dada pela Emenda Constitucional n° 21, de 14/02/2006. §2° - Desde a expedição do diploma, os membros da Assembleia Legislativa  não poderão ser presos, salvo em flagrante de crime inafiançável.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §2° - Desde a expedição do diploma, os membros da Assembleia Legislativa  não poderão ser presos, salvo em flagrante de crime inafiançável. Nesse caso, os autos serão remetidos dentro de vinte e quatro horas à Assembleia Legislativa, para que, pelo voto da maioria de seus\nmembros, resolva sobre a prisão. ( NR)\n- § 2° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.',
#   'segment': '§2° - Desde a expedição do diploma, os membros da Assembleia Legislativa  não poderão ser presos, salvo em flagrante de crime inafiançável. Nesse caso, os autos serão remetidos dentro de vinte e quatro horas à Assembleia Legislativa, para que, pelo voto da maioria de seus\nmembros, resolva sobre a prisão. ( NR)\n- § 2° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: NR)\n- § 2° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §3° - Recebida a denún cia contra Deputado, por crime ocorrido após a diplo mação, o Tribunal de Justiça dará ciência à Assembleia Legislativa\nque, por iniciativa de partido político nela representado e pelo voto da maioria de seus membros, poderá, até a decisão final, sustar o\nandamento da ação. ( NR)\n- § 3° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.',
#   'segment': 'NR)\n- § 2° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §3° - Recebida a denún cia contra Deputado, por crime ocorrido após a diplo mação, o Tribunal de Justiça dará ciência à Assembleia Legislativa\nque, por iniciativa de partido político nela representado e pelo voto da maioria de seus membros, poderá, até a decisão final, sustar o\nandamento da ação. ( NR)\n- § 3° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: NR)\n- § 3° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §4° - O pedido de sustação será apreciad o pela Assembleia Legislativa no prazo improrrogável de quarenta e cinco dias do seu recebimento\npela Mesa Diretora. ( NR)\n- § 4° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.',
#   'segment': 'NR)\n- § 3° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §4° - O pedido de sustação será apreciad o pela Assembleia Legislativa no prazo improrrogável de quarenta e cinco dias do seu recebimento\npela Mesa Diretora. ( NR)\n- § 4° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: NR)\n- § 4° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §5° -  A sustação do processo suspende a prescrição, enquanto durar o mandato. ( NR)\n- § 5° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.',
#   'segment': 'NR)\n- § 4° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §5° -  A sustação do processo suspende a prescrição, enquanto durar o mandato. ( NR)\n- § 5° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: NR)\n- § 5° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §6° - Os Deputados não serão obrigados a testemunhar sobre informações recebidas ou prestadas em razão do exercício do mandato, nem\nsobre as pessoas que lhes confiaram ou deles receberam informações. ( NR)\n- § 6° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.',
#   'segment': 'NR)\n- § 5° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §6° - Os Deputados não serão obrigados a testemunhar sobre informações recebidas ou prestadas em razão do exercício do mandato, nem\nsobre as pessoas que lhes confiaram ou deles receberam informações. ( NR)\n- § 6° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: NR)\n- § 6° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §7° - A incorp oração às Forças Armadas  de Deputados, embora militares e ainda que em tempo de guerra, dependerá de prévia licença da\nAssembléia Legislativa. ( NR)\n- § 7° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 4/84\n§8° - As imuni dades de Deputados subsistirão durante o estado de sítio, só podendo ser suspensas mediante o voto de dois terços dos\nmembros da Assembléia Legislativa , nos casos de atos praticados fora do recinto dessa Casa, que sejam incompatíveis com a execução da\nmedida. (',
#   'segment': 'NR)\n- § 6° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §7° - A incorp oração às Forças Armadas  de Deputados, embora militares e ainda que em tempo de guerra, dependerá de prévia licença da\nAssembléia Legislativa. ( NR)\n- § 7° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 4/84\n§8° - As imuni dades de Deputados subsistirão durante o estado de sítio, só podendo ser suspensas mediante o voto de dois terços dos\nmembros da Assembléia Legislativa , nos casos de atos praticados fora do recinto dessa Casa, que sejam incompatíveis com a execução da\nmedida. ('},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: NR)\n- § 7° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 4/84\n§8° - As imuni dades de Deputados subsistirão durante o estado de sítio, só podendo ser suspensas mediante o voto de dois terços dos\nmembros da Assembléia Legislativa , nos casos de atos praticados fora do recinto dessa Casa, que sejam incompatíveis com a execução da\nmedida. ( NR)\n- § 8° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §9° - O Deput ado ou a Deputada, sempre que representando uma das Comissões Permanentes, Comissões Parlamentares de Inquérito ou a\nAssembleia Legislativa, neste último caso mediante deliberação do Plenário, terá livre acesso às repartições públicas, podendo diligenciar\npessoalmente junto aos órgãos da administração direta e indireta e agências reguladoras, sujeitando-se os respectivos responsáveis às\nsanções civis, administrativas e penais previstas em lei, na hipótese de recusa ou omissão. (',
#   'segment': 'NR)\n- § 7° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002.07/06/2024, 11:38 CONSTITUIÇÃO ESTADUAL, DE 05 DE OUTUBRO DE 1989 - Assembleia Legislativa do Estado de São Paulo\nhttps://www.al.sp.gov.br/repositorio/legislacao/constituicao/1989/compilacao-constituicao-0-05.10.1989.html 4/84\n§8° - As imuni dades de Deputados subsistirão durante o estado de sítio, só podendo ser suspensas mediante o voto de dois terços dos\nmembros da Assembléia Legislativa , nos casos de atos praticados fora do recinto dessa Casa, que sejam incompatíveis com a execução da\nmedida. ( NR)\n- § 8° com redação dada pela Emenda Constitucional n° 14, de 12/03/2002. §9° - O Deput ado ou a Deputada, sempre que representando uma das Comissões Permanentes, Comissões Parlamentares de Inquérito ou a\nAssembleia Legislativa, neste último caso mediante deliberação do Plenário, terá livre acesso às repartições públicas, podendo diligenciar\npessoalmente junto aos órgãos da administração direta e indireta e agências reguladoras, sujeitando-se os respectivos responsáveis às\nsanções civis, administrativas e penais previstas em lei, na hipótese de recusa ou omissão. ('},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §9° - O Deput ado ou a Deputada, sempre que representando uma das Comissões Permanentes, Comissões Parlamentares de Inquérito ou a\nAssembleia Legislativa, neste último caso mediante deliberação do Plenário, terá livre acesso às repartições públicas, podendo diligenciar\npessoalmente junto aos órgãos da administração direta e indireta e agências reguladoras, sujeitando-se os respectivos responsáveis às\nsanções civis, administrativas e penais previstas em lei, na hipótese de recusa ou omissão. ( NR)\n- § 9° com redação dada pela Emenda Constitucional n° 31, de 21/10/2009. §9°-A  - Revogado.',
#   'segment': '§9° - O Deput ado ou a Deputada, sempre que representando uma das Comissões Permanentes, Comissões Parlamentares de Inquérito ou a\nAssembleia Legislativa, neste último caso mediante deliberação do Plenário, terá livre acesso às repartições públicas, podendo diligenciar\npessoalmente junto aos órgãos da administração direta e indireta e agências reguladoras, sujeitando-se os respectivos responsáveis às\nsanções civis, administrativas e penais previstas em lei, na hipótese de recusa ou omissão. ( NR)\n- § 9° com redação dada pela Emenda Constitucional n° 31, de 21/10/2009. §9°-A  - Revogado.'},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §9°-A  - Revogado. - § 9°-A revogado pela Emenda Constitucional n° 31, de 21/10/2009. §10 - No caso de inviola bilidade por quaisquer opiniões, palavras, votos e manifestações verbais ou escritas de deputado em razão de sua\natividade parlamentar , impende-se o arquivamento de inquérito policial e o imediato não-conhecimento de ação civil ou penal promovida com\ninobservância deste direito do Poder Legislativo, independentemente de prévia comunicação ao deputado ou à Assembleia Legislativa. (',
#   'segment': '§9°-A  - Revogado. - § 9°-A revogado pela Emenda Constitucional n° 31, de 21/10/2009. §10 - No caso de inviola bilidade por quaisquer opiniões, palavras, votos e manifestações verbais ou escritas de deputado em razão de sua\natividade parlamentar , impende-se o arquivamento de inquérito policial e o imediato não-conhecimento de ação civil ou penal promovida com\ninobservância deste direito do Poder Legislativo, independentemente de prévia comunicação ao deputado ou à Assembleia Legislativa. ('},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §10 - No caso de inviola bilidade por quaisquer opiniões, palavras, votos e manifestações verbais ou escritas de deputado em razão de sua\natividade parlamentar , impende-se o arquivamento de inquérito policial e o imediato não-conhecimento de ação civil ou penal promovida com\ninobservância deste direito do Poder Legislativo, independentemente de prévia comunicação ao deputado ou à Assembleia Legislativa. ( NR)\n- § 10 acrescentado pela Emenda Constitucional n° 15, de 15/05/2002. §11 - Salvo as hipótes es do § 10, os procedimentos investigatórios e as suas diligências de caráter instrutório somente serão promovidos\nperante o Tribunal de Justiça, e sob seu controle, a quem caberá ordenar toda e qualquer providência necessária à obtenção de dados\nprobatórios para demonstração de alegado delito de deputado. (',
#   'segment': '§10 - No caso de inviola bilidade por quaisquer opiniões, palavras, votos e manifestações verbais ou escritas de deputado em razão de sua\natividade parlamentar , impende-se o arquivamento de inquérito policial e o imediato não-conhecimento de ação civil ou penal promovida com\ninobservância deste direito do Poder Legislativo, independentemente de prévia comunicação ao deputado ou à Assembleia Legislativa. ( NR)\n- § 10 acrescentado pela Emenda Constitucional n° 15, de 15/05/2002. §11 - Salvo as hipótes es do § 10, os procedimentos investigatórios e as suas diligências de caráter instrutório somente serão promovidos\nperante o Tribunal de Justiça, e sob seu controle, a quem caberá ordenar toda e qualquer providência necessária à obtenção de dados\nprobatórios para demonstração de alegado delito de deputado. ('},
#  {'title': 'Constituição Estadual SP',
#   'contents': '[Constituição Estadual SP]: §11 - Salvo as hipótes es do § 10, os procedimentos investigatórios e as suas diligências de caráter instrutório somente serão promovidos\nperante o Tribunal de Justiça, e sob seu controle, a quem caberá ordenar toda e qualquer providência necessária à obtenção de dados\nprobatórios para demonstração de alegado delito de deputado. ( NR)\n- § 11 acrescentado pela Emenda Constitucional n° 15, de 15/05/2002. Artigo 15 -  Os Deputados não poderão:\nI - desde a expedição do diploma:\na) firmar ou manter contrato com pessoa jurídica de direito público, autarquia, empresa pública, sociedade de economia mista ou empresa\nconcessionária de serviço público, salvo quando o contrato obedecer a cláusulas uniformes;\nb) aceitar ou exercer cargo, função ou emprego remunerado, incluindo os de que sejam demissíveis "ad nutum", nas entidades constantes da\nalínea anterior;\nII - desde a posse:\na) ser proprietários, controladores ou diretores de empresa que goze de favor decorrente de contrato com pessoa jurídica de direito público, ou\nnela exercer função remunerada;\nb) ocupar cargo ou função de que sejam demissíveis "ad nutum", nas entidades referidas na alínea "a" do inciso I;\nc) patrocinar causa em que seja interessada qualquer das entidades a que se refere a alínea "a" do inciso I;\nd) ser titulares de mais de um cargo ou mandato eletivo federal, estadual ou municipal.',
#   'segment': '§11 - Salvo as hipótes es do § 10, os procedimentos investigatórios e as suas diligências de caráter instrutório somente serão promovidos\nperante o Tribunal de Justiça, e sob seu controle, a quem caberá ordenar toda e qualquer providência necessária à obtenção de dados\nprobatórios para demonstração de alegado delito de deputado. ( NR)\n- § 11 acrescentado pela Emenda Constitucional n° 15, de 15/05/2002. Artigo 15 -  Os Deputados não poderão:\nI - desde a expedição do diploma:\na) firmar ou manter contrato com pessoa jurídica de direito público, autarquia, empresa pública, sociedade de economia mista ou empresa\nconcessionária de serviço público, salvo quando o contrato obedecer a cláusulas uniformes;\nb) aceitar ou exercer cargo, função ou emprego remunerado, incluindo os de que sejam demissíveis "ad nutum", nas entidades constantes da\nalínea anterior;\nII - desde a posse:\na) ser proprietários, controladores ou diretores de empresa que goze de favor decorrente de contrato com pessoa jurídica de direito público, ou\nnela exercer função remunerada;\nb) ocupar cargo ou função de que sejam demissíveis "ad nutum", nas entidades referidas na alínea "a" do inciso I;\nc) patrocinar causa em que seja interessada qualquer das entidades a que se refere a alínea "a" do inciso I;\nd) ser titulares de mais de um cargo ou mandato eletivo federal, estadual ou municipal.'},
#  {'title': 'Constituição Estadual SP',
# ...
#   'segment': 'DO   DEPARTAMENTO  \n Artigo 144. Os Institutos e as Faculdades \nterão, como unidade básica, o Departamento, definido \nno Artigo 29, ressalvando- se o disposto no Parágrafo \nÚnico deste mesmo Artigo, e o seu número não é limitado, podendo existir quantos forem julgados \nnecessários ao desenvolvimento do ensino, da pesquisa e da extensão. REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS  -  Secretaria Geral, janeiro de 2024 .'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS  -  Secretaria Geral, janeiro de 2024 . . 27 Artigo 145.',
#   'segment': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS  -  Secretaria Geral, janeiro de 2024 . . 27 Artigo 145.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: 27 Artigo 145. Os Dep artamentos elaborarão os \nseus planos de trabalho, distribuindo os encargos de \nensino, pesquisa, extensão e administração aos docentes \nque os integrem. Artigo 146.',
#   'segment': '27 Artigo 145. Os Dep artamentos elaborarão os \nseus planos de trabalho, distribuindo os encargos de \nensino, pesquisa, extensão e administração aos docentes \nque os integrem. Artigo 146.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: Artigo 146. Cabe aos Departamentos, na esfera \nde sua competência e especialidade:  \nI. garantir o ofereciment o das disciplinas \nconstantes do currículo dos cursos de graduação, da pós -graduação e extensão ; \nII. ministrar os cursos de pós -graduação;  \nIII.',
#   'segment': 'Artigo 146. Cabe aos Departamentos, na esfera \nde sua competência e especialidade:  \nI. garantir o ofereciment o das disciplinas \nconstantes do currículo dos cursos de graduação, da pós -graduação e extensão ; \nII. ministrar os cursos de pós -graduação;  \nIII.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: ministrar os cursos de pós -graduação;  \nIII. planejar, organizar e realizar ações de  extensão, sejam elas cursos, eventos, prestação de serviços, programas ou projetos ; \nIV. organizar o trabalho docente e discente, de \nmodo a obter o máximo rendimento didático;  \nV. promover e apoiar o oferecimento de \ndisciplinas e a realização das demais \natividades de extensão ; \nVI.',
#   'segment': 'ministrar os cursos de pós -graduação;  \nIII. planejar, organizar e realizar ações de  extensão, sejam elas cursos, eventos, prestação de serviços, programas ou projetos ; \nIV. organizar o trabalho docente e discente, de \nmodo a obter o máximo rendimento didático;  \nV. promover e apoiar o oferecimento de \ndisciplinas e a realização das demais \natividades de extensão ; \nVI.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: organizar o trabalho docente e discente, de \nmodo a obter o máximo rendimento didático;  \nV. promover e apoiar o oferecimento de \ndisciplinas e a realização das demais \natividades de extensão ; \nVI. promover e organizar a pesquisa e o \ntreinamento especializados. Parágrafo Único.',
#   'segment': 'organizar o trabalho docente e discente, de \nmodo a obter o máximo rendimento didático;  \nV. promover e apoiar o oferecimento de \ndisciplinas e a realização das demais \natividades de extensão ; \nVI. promover e organizar a pesquisa e o \ntreinamento especializados. Parágrafo Único.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: Parágrafo Único. Além das atribuições acima \nespecificadas, compete, ainda, ao Departamento:  \n1. elaborar seus planos de trabalho;  \n2.',
#   'segment': 'Parágrafo Único. Além das atribuições acima \nespecificadas, compete, ainda, ao Departamento:  \n1. elaborar seus planos de trabalho;  \n2.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: elaborar seus planos de trabalho;  \n2. atribuir encargos ao pessoal pertencente ao mesmo;  \n3. fazer a distribuição de disciplinas pelos docentes, assim como propor a criação de novas disciplinas; \n4.',
#   'segment': 'elaborar seus planos de trabalho;  \n2. atribuir encargos ao pessoal pertencente ao mesmo;  \n3. fazer a distribuição de disciplinas pelos docentes, assim como propor a criação de novas disciplinas; \n4.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: fazer a distribuição de disciplinas pelos docentes, assim como propor a criação de novas disciplinas; \n4. propor a admissão de docentes, bem como, se \nfor o caso, de outros servidores. Artigo 147.',
#   'segment': 'fazer a distribuição de disciplinas pelos docentes, assim como propor a criação de novas disciplinas; \n4. propor a admissão de docentes, bem como, se \nfor o caso, de outros servidores. Artigo 147.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: Artigo 147. Cada Departamento será \ncoordenado:  \nI. por um Chefe, com mandato de 2 (dois) anos, docente, portador no mínimo do título de \nDoutor, eleito pelos doce ntes em exercício no \nDepartamento, ressalvado o disposto no Artigo 153;  \nII. por um Conselho de Departamento;   Parágrafo Único.',
#   'segment': 'Artigo 147. Cada Departamento será \ncoordenado:  \nI. por um Chefe, com mandato de 2 (dois) anos, docente, portador no mínimo do título de \nDoutor, eleito pelos doce ntes em exercício no \nDepartamento, ressalvado o disposto no Artigo 153;  \nII. por um Conselho de Departamento;   Parágrafo Único.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: por um Conselho de Departamento;   Parágrafo Único. Cabe ao Chefe do \nDepartamento:  \n1. representar o Departamento no Conselho Interdepartamental e na Congregação;  \n2.',
#   'segment': 'por um Conselho de Departamento;   Parágrafo Único. Cabe ao Chefe do \nDepartamento:  \n1. representar o Departamento no Conselho Interdepartamental e na Congregação;  \n2.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: representar o Departamento no Conselho Interdepartamental e na Congregação;  \n2. executar as deliberações d o Departamento, \nzelando pelo cumprimento das obrigações de seu pessoal, bem como das atividades \nde ensino, pesquisa e extensão;  \n3. manter a disciplina no Departamento.',
#   'segment': 'representar o Departamento no Conselho Interdepartamental e na Congregação;  \n2. executar as deliberações d o Departamento, \nzelando pelo cumprimento das obrigações de seu pessoal, bem como das atividades \nde ensino, pesquisa e extensão;  \n3. manter a disciplina no Departamento.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: manter a disciplina no Departamento. Artigo 148. A composição do Conselho \nDepartamental, será aprovada pela Congregação e \nconst ará do Regimento da Unidade.',
#   'segment': 'manter a disciplina no Departamento. Artigo 148. A composição do Conselho \nDepartamental, será aprovada pela Congregação e \nconst ará do Regimento da Unidade.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: A composição do Conselho \nDepartamental, será aprovada pela Congregação e \nconst ará do Regimento da Unidade. § 1º. O número de membros docentes \ncorresponderá, no mínimo, a 70% do total dos \nmembros do Conselho de Departamento. § 2º. O Conselho de Departamento somente \npoderá deliberar com a presença da maioria dos seus membros.',
#   'segment': 'A composição do Conselho \nDepartamental, será aprovada pela Congregação e \nconst ará do Regimento da Unidade. § 1º. O número de membros docentes \ncorresponderá, no mínimo, a 70% do total dos \nmembros do Conselho de Departamento. § 2º. O Conselho de Departamento somente \npoderá deliberar com a presença da maioria dos seus membros.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: § 2º. O Conselho de Departamento somente \npoderá deliberar com a presença da maioria dos seus membros. Artigo 149. Um Departamento só será \nimplantado quando atender, simultaneamente, às \nseguintes condições:  \nI. existência de atividades de ensino, \npesquisa e extensão em nível adequado ; \nII.',
#   'segment': '§ 2º. O Conselho de Departamento somente \npoderá deliberar com a presença da maioria dos seus membros. Artigo 149. Um Departamento só será \nimplantado quando atender, simultaneamente, às \nseguintes condições:  \nI. existência de atividades de ensino, \npesquisa e extensão em nível adequado ; \nII.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: Um Departamento só será \nimplantado quando atender, simultaneamente, às \nseguintes condições:  \nI. existência de atividades de ensino, \npesquisa e extensão em nível adequado ; \nII. existência de 02 (duas) categorias \ndocentes, no mínimo;  \nIII. existência de 12 (doze ) docentes, pelo \nmenos, com título de Doutor.',
#   'segment': 'Um Departamento só será \nimplantado quando atender, simultaneamente, às \nseguintes condições:  \nI. existência de atividades de ensino, \npesquisa e extensão em nível adequado ; \nII. existência de 02 (duas) categorias \ndocentes, no mínimo;  \nIII. existência de 12 (doze ) docentes, pelo \nmenos, com título de Doutor.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: existência de 12 (doze ) docentes, pelo \nmenos, com título de Doutor. Parágrafo Único. Verificada a existência de \ncondições mínimas, o Diretor da Unidade, ouvida a \nCongregação, proporá ao Conselho Universitário, a criação do Departamento, devendo ainda constar da \nproposta:  \n1.',
#   'segment': 'existência de 12 (doze ) docentes, pelo \nmenos, com título de Doutor. Parágrafo Único. Verificada a existência de \ncondições mínimas, o Diretor da Unidade, ouvida a \nCongregação, proporá ao Conselho Universitário, a criação do Departamento, devendo ainda constar da \nproposta:  \n1.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: Verificada a existência de \ncondições mínimas, o Diretor da Unidade, ouvida a \nCongregação, proporá ao Conselho Universitário, a criação do Departamento, devendo ainda constar da \nproposta:  \n1. relação  do pessoal docente e designação do \norientador que procederá a sua implantação;  \n2. o número e a respectiva função dos servidores que farão parte do \nDepartamento;  \n3.',
#   'segment': 'Verificada a existência de \ncondições mínimas, o Diretor da Unidade, ouvida a \nCongregação, proporá ao Conselho Universitário, a criação do Departamento, devendo ainda constar da \nproposta:  \n1. relação  do pessoal docente e designação do \norientador que procederá a sua implantação;  \n2. o número e a respectiva função dos servidores que farão parte do \nDepartamento;  \n3.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: o número e a respectiva função dos servidores que farão parte do \nDepartamento;  \n3. as instalações e equipamentos existentes;  \n4. as disciplinas que o integrarão e os respectivos respon sáveis.',
#   'segment': 'o número e a respectiva função dos servidores que farão parte do \nDepartamento;  \n3. as instalações e equipamentos existentes;  \n4. as disciplinas que o integrarão e os respectivos respon sáveis.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: as disciplinas que o integrarão e os respectivos respon sáveis. 28                               RE GIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS -  Secretaria Geral , janeiro de 2024. Artigo 149.A. A fusão, a manutenção ou a \ndivisão de Departamento fica condicionada ao \natendimento dos requisitos expressos nos Incisos I \ne II do artigo 149, bem como na existência de, pelo menos, 10 (dez) docentes.',
#   'segment': 'as disciplinas que o integrarão e os respectivos respon sáveis. 28                               RE GIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS -  Secretaria Geral , janeiro de 2024. Artigo 149.A. A fusão, a manutenção ou a \ndivisão de Departamento fica condicionada ao \natendimento dos requisitos expressos nos Incisos I \ne II do artigo 149, bem como na existência de, pelo menos, 10 (dez) docentes.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: Artigo 149.A. A fusão, a manutenção ou a \ndivisão de Departamento fica condicionada ao \natendimento dos requisitos expressos nos Incisos I \ne II do artigo 149, bem como na existência de, pelo menos, 10 (dez) docentes. Parágrafo Único. O Conselho Universitário \npoderá, em caráter excepcional, e pela maioria simples de seus membros, autorizar por período não superior a 24 meses, o funcionamento de Departamento com \nnúmero inferior ao disposto no caput, à vista de \njustificativas fundadas em razões acadêm icas.',
#   'segment': 'Artigo 149.A. A fusão, a manutenção ou a \ndivisão de Departamento fica condicionada ao \natendimento dos requisitos expressos nos Incisos I \ne II do artigo 149, bem como na existência de, pelo menos, 10 (dez) docentes. Parágrafo Único. O Conselho Universitário \npoderá, em caráter excepcional, e pela maioria simples de seus membros, autorizar por período não superior a 24 meses, o funcionamento de Departamento com \nnúmero inferior ao disposto no caput, à vista de \njustificativas fundadas em razões acadêm icas.'},
#  {'title': 'REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS',
#   'contents': '[REGIMENTO GERAL DA UNIVERSIDADE ESTADUAL DE CAMPINAS]: O Conselho Universitário \npoderá, em caráter excepcional, e pela maioria simples de seus membros, autorizar por período não superior a 24 meses, o funcionamento de Departamento com \nnúmero inferior ao disposto no caput, à vista de \njustificativas fundadas em razões acadêm icas. Artigo 150. O Conselho Universitário, ouvida a \nCâmara de Ensino, Pesquisa e Extensão, deliberará sobre \na criação do Departamento e o início de sua instalação.',
#   'segment': 'O Conselho Universitário \npoderá, em caráter excepcional, e pela maioria simples de seus membros, autorizar por período não superior a 24 meses, o funcionamento de Departamento com \nnúmero inferior ao disposto no caput, à vista de \njustificativas fundadas em razões acadêm icas. Artigo 150. O Conselho Universitário, ouvida a \nCâmara de Ensino, Pesquisa e Extensão, deliberará sobre \na criação do Departamento e o início de sua instalação.'},
#  ...]

# %%
initial_prompt = """
Você é um assistente digital especializado em regulamentações, normas e legislação da Unicamp. Seu papel é utilizar uma biblioteca digital de documentos oficiais (como resoluções, estatutos e diretrizes) para responder precisamente a perguntas relacionadas a esses documentos. Suas respostas devem ser estritamente baseadas nas informações contidas nos documentos e não devem incluir conhecimento prévio ou externo. Além disso, responda em PT BR.

Ao responder a uma pergunta, siga estes passos:

1. **Identificação do Documento**: Determine qual(is) documento(s) da biblioteca são mais relevantes para a pergunta. Cite o nome do documento entre colchetes, por exemplo, [Resolução GR-018/2018].

2. **Extrato Relevante**: Localize e transcreva o trecho específico do documento que diretamente responde ou esclarece a pergunta. Se necessário, inclua múltiplos trechos para cobrir todos os aspectos da pergunta.

3. **Explicação do Raciocínio**: Explique claramente como os trechos citados apoiam sua resposta. Esta explicação deve conectar os pontos dos documentos à pergunta, esclarecendo qualquer interpretação ou inferência que foi necessária.

4. **Resposta Concisa**: Forneça uma resposta direta à pergunta, limitada a no máximo 30 palavras. Esta resposta deve ser uma síntese do que foi explicado anteriormente.

5. **Considerações a serem feitas para responder uma pergunta:**:
   - **Relevância**: Verifique se a resposta aborda todos os aspectos da pergunta.
   - **Fidelidade**: Assegure que a resposta esteja fielmente baseada nos documentos.
   - **Recall Contextual**: Avalie se todos os contextos relevantes foram considerados na resposta.
   - **Precisão Contextual**: Garanta que os trechos citados são diretamente relevantes para a pergunta.

Exemplo de pergunta: 'Qual o procedimento para a submissão de projetos de pesquisa na Unicamp que envolvam parcerias internacionais?'
Exemplo de resposta: Evidence: [Deliberação CAD-A-009/2023]: Esta deliberação estabelece os critérios quantitativos mínimos para progressão na Carreira de Pesquisador na Faculdade de Ciências Médicas. Para progressão de Pq-C para Pq-B, o pesquisador deve alcançar 190 pontos, incluindo um mínimo de 18 pontos em projetos de pesquisa coordenados e 70 pontos em atividades de pesquisa de alto impacto. Para a progressão de Pq-B para Pq-A, são necessários 380 pontos, com um mínimo de 36 pontos em projetos de pesquisa coordenados e 120 pontos em pesquisas de alto impacto. Answer: '[Deliberação CAD-A-009/2023]: A Deliberação CAD-A-009/2023 da Universidade Estadual de Campinas define o Perfil Quantitativo Mínimo para a ascensão aos níveis superiores da Carreira de Pesquisador (Pq) na Faculdade de Ciências Médicas. Para avançar do nível Pq-C para Pq-B, um pesquisador deve alcançar um total de 190 pontos, distribuídos entre projetos de pesquisa e outras atividades científicas. Para a progressão do nível Pq-B para Pq-A, o pesquisador deve somar 380 pontos, demonstrando maior liderança e impacto em sua área. Estes pontos são acumulados a partir de projetos de pesquisa, publicações, e contribuições a atividades acadêmicas e administrativas, conforme detalhado nos critérios específicos de pontuação. 'Evidence: '
"""

# %%
def mensagem_user(numExemplo, pergunta, lista_documentos):
  doc_com_id = [ f"{lista_documentos[i]}" for i in range(len(lista_documentos))]
  return f"Example {numExemplo}\n\n" + "\n\n".join(doc_com_id) + f"\n\nQuestion: {pergunta}"


def mensagem_assistant(evidencia, resposta):
  return f"Evidence: {evidencia}\n\nAnswer: {resposta}"


few_shot_examples = [
    {"user": "", "assistant": ""},
    {"user": "", "assistant": ""},
]
few_shot_examples[0]["user"] = mensagem_user(1, "Pink Floyd tem uma música sobre a Riviera Francesa?", [
    "[Nome do documento 1]: \"San Tropez\" é a quarta faixa do álbum Meddle da banda Pink Floyd. Esta música foi uma das várias consideradas para o álbum de melhores sucessos da banda, Echoes: The Best of Pink Floyd.",
    "[Nome do documento 2]: A Riviera Francesa (conhecida em francês como Côte d'Azur [kot daˈzyʁ]; Occitano: Còsta d'Azur [ˈkɔstɔ daˈzyɾ]; tradução literal \"Costa Azul\") é a costa do Mediterrâneo no sudeste da França. Não há um limite oficial, mas geralmente considera-se que se estende de Cassis, Toulon ou Saint-Tropez a oeste até Menton na fronteira França-Itália a leste, onde se junta a Riviera Italiana. A costa está inteiramente dentro da região de Provence-Alpes-Côte d'Azur (Região Sul) da França. O Principado de Mônaco é uma semi-enclave dentro da região, cercado por três lados pela França e de frente para o Mediterrâneo.",
    "[Nome do documento 3]: Moon também prometeu transparência em sua presidência, mudando a residência presidencial da palaciana e isolada Casa Azul para um complexo governamental existente no centro de Seul.",
    "[Nome do documento 4]: Saint-Tropez (EUA: /ˌsæn troʊˈpeɪ/ SAN-troh-PAY, francês: [sɛ̃ tʁɔpe]; Occitano: Sant-Tropetz, pronunciado [san(t) tʀuˈpes]) é uma cidade na Riviera Francesa, 68 quilômetros (42 milhas) a oeste de Nice e 100 quilômetros (62 milhas) a leste de Marselha no departamento de Var da região de Provence-Alpes-Côte d'Azur de Occitania, sul da França."
])
few_shot_examples[0]["assistant"] = mensagem_assistant("\"San Tropez\" é uma música do Pink Floyd sobre a Riviera Francesa, de acordo com o trecho '\"San Tropez\" é a quarta faixa do álbum Meddle da banda Pink Floyd' em [Nome do documento 1]. Saint-Tropez é uma cidade na Riviera Francesa, de acordo com o trecho 'Saint-Tropez (EUA: /ˌsæn troʊˈpeɪ/ SAN-troh-PAY, francês: [sɛ̃ tʁɔpe]; Occitano: Sant-Tropetz, pronunciado [san(t) tʀuˈpes]) é uma cidade na Riviera Francesa' de [Nome do documento 4]", "sim")
few_shot_examples[1]["user"] = mensagem_user(2, "Em que data ocorreu o terremoto de Loma Prieta?", [
    "[Nome do documento 1]: O terremoto de Loma Prieta de 1989 ocorreu na Costa Central da Califórnia em 17 de outubro às hora local (1989-10-18 00:04 UTC). O choque foi centrado no Parque Estadual da Floresta de Nisene Marks aproximadamente 10 mi a nordeste de Santa Cruz em uma seção do Sistema de Falhas de San Andreas e foi nomeado após o pico Loma Prieta nas Montanhas de Santa Cruz. Com uma magnitude de 6.9 e uma intensidade máxima de Mercalli Modificado de IX (Violento), o choque foi responsável por 63 mortes e 3.757 feridos.",
    "[Nome do documento 2]: Foreshocks. Os eventos de 5.3 de junho de 1988 e de 5.4 de agosto de 1989 também ocorreram em falhas reversas oblíquas anteriormente desconhecidas e estavam dentro de 3 mi do epicentro do principal abalo de Loma Prieta M6.9, perto da interseção das falhas de San Andreas e Sargent. O deslocamento total para esses choques foi relativamente pequeno (aproximadamente 4 in de deslizamento lateral e substancialmente menos deslizamento reverso) e embora tenham ocorrido em falhas separadas e bem antes do abalo principal, um grupo de sismólogos considerou esses como precursores devido à sua localização no espaço e tempo em relação ao evento principal.",
    "[Nome do documento 3]: O choque de 27 de junio de 1988 ocorreu com uma intensidade máxima de VI (Forte). Seus efeitos incluíram janelas quebradas em Los Gatos e outros danos leves em Holy City, onde foi observado um aumento de fluxo em um poço de água. Mais longe das Montanhas de Santa Cruz, pedaços de concreto caíram de uma estrutura de estacionamento no Sunnyvale Town Center, um shopping de dois níveis no condado de Santa Clara.",
    "[Nome do documento 4]: O terremoto de Loma Prieta de 6.9 ocorreu em 17 de outubro de 1989. A ruptura estava relacionada ao sistema de falhas de San Andreas e afetou toda a área da Baía de San Francisco com uma intensidade máxima de Mercalli de IX (Violento). Muitas estruturas em Oakland foram gravemente danificadas, incluindo a porção de dois andares da Interestadual 880 que desabou.",
])
few_shot_examples[1]["assistant"] = mensagem_assistant("De acordo com o trecho 'O terremoto de Loma Prieta de 1989 ocorreu na Costa Central da Califórnia em 17 de outubro às hora local (1989-10-18 00:04 UTC)' de [Nome do documento 1] e o trecho 'O terremoto de Loma Prieta de 6.9 ocorreu em 17 de outubro de 1989' de [Nome do documento 4], o terremoto de Loma Prieta ocorreu em 17 de outubro de 1989", "1989-10-17")


initial_messages=[
    {"role": "system", "content": initial_prompt},
    {"role": "user", "content": few_shot_examples[0]["user"]},
    {"role": "assistant", "content": few_shot_examples[0]["assistant"]},
    {"role": "user", "content": few_shot_examples[1]["user"]},
    {"role": "assistant", "content": few_shot_examples[1]["assistant"]}
]

# %%
def get_passagens(pergunta, n=5):
  passagens = []
  resultado_bm25 = buscador.pesquisar(pergunta)

  for i in range(min(len(resultado_bm25), n)):
    segmento_id = resultado_bm25[i][0]
    segment = artigos_segmentados[segmento_id]['contents'] # changed segment to contents
    passagens.append(segment)

  return passagens

# %%
# Teste de como chamar o mensagem_user usando o retorno do BM25:

teste_pergunta = test_set[0]['question']
teste_passagens = get_passagens(teste_pergunta, 5)
print(mensagem_user(2, teste_pergunta, teste_passagens))
# Out:
# Example 2
#
# [Constituição Federal]: (Incluído pela Emenda Constitucional nº 45, de 2004)
#   Art. 129. São funções institucionais do Ministério Público:07/06/2024, 11:39 Constituição
# www.planalto.gov.br/ccivil_03/constituicao/constituicao.htm 91/226
# I - promover , privativamente, a ação penal pública, na forma da lei;
# II - zelar pelo efetivo respeito dos Poderes Públicos e dos serviços de relevância pública aos direitos assegurados nesta Constituição, promovendo as medidas necessárias
# a sua garantia;
# III - promover o inquérito civil e a ação civil pública, para a proteção do patrimônio público e social, do meio ambiente e de outros interesses difusos e coletivos;
# IV - promover a ação de inconstitucionalidade ou representação para fins de intervenção da União e dos Estados, nos casos previstos nesta Constituição;
# V - defender judicialmente os direitos e interesses das populações indígenas;
# VI - expedir notificações nos procedimentos administrativos de sua competência, requisitando informações e documentos para instruí-los, na forma da lei complementar
# respectiva;
# VII - exercer o controle externo da atividade policial, na forma da lei complementar mencionada no artigo anterior;
# VIII - requisitar diligências investigatórias e a instauração de inquérito policial, indicados os fundamentos jurídicos de suas manifestações processuais;
# IX - exerce r outras funções que lhe forem conferidas, desde que compatíveis com sua finalidade, sendo-lhe vedada a representação judicial e a consultoria jurídica de
# entidades públicas. § 1º - A legitimação do Ministério Público para as ações civis previstas neste artigo  não impede a de terceiros, nas mesmas hipóteses, segundo o disposto nesta
# Constituição e na lei.
#
# [Constituição Federal]: (Incluído pela Emenda Constitucional nº 132, de 2023)
#   Art. 156-B.  Os Estados, o Distrito Federal e os Municípios exercerão de forma integrada, exclusivamente por meio do Comitê Gestor do Imposto sobre Bens e
# Serviços, nos termos e limites estabelecidos nesta Constituição e em lei complementar , as seguintes competências administrativas relativas ao imposto de que trata o art. 156-
# A:     (Incluído pela Emenda Constitucional nº 132, de 2023)
# I - editar regulamento único e uniformizar a interpretação e a aplicação da legislação do imposto;     (Incluído pela Emenda Constitucional nº 132, de 2023)
# II - arrecadar o imposto, efetuar as comp ensações e distribuir o produto da arrecadação entre Estados, Distrito Federal e Municípios;     (Incluído pela Emenda
# Constitucional nº 132, de 2023)
# III - decidir o contencioso administrativo. (Incluído pela Emenda Constitucional nº 132, de 2023)
# § 1º O Com itê Gestor do Imposto sobre Bens e Serviços, entidade pública sob regime especial, terá independência técnica, administrativa, orçamentária e financeira. (Incluído pela Emenda Constitucional nº 132, de 2023)
# § 2º Na forma da lei complementar:     (Incluído pela Emenda Constitucional nº 132, de 2023)
# I - os Estados, o Distri to Federal e os Municípios serão representados, de forma paritária, na instância máxima de deliberação do Comitê Gestor do Imposto sobre Bens e
# Serviços;     (Incluído pela Emenda Constitucional nº 132, de 2023)
# II - será assegurada a alternância na presid ência do Comitê Gestor entre o conjunto dos Estados e o Distrito Federal e o conjunto dos Municípios e o Distrito Federal;
# (Incluído pela Emenda Constitucional nº 132, de 2023)
# III - o Comitê Gestor será financiado por percentual do produto da arrecadação do imposto destinado a cada ente federativo;     (Incluído pela Emenda Constitucional nº
# 132, de 2023)
# IV - o controle externo do Comitê Gestor será exercido pelos Estados, pelo Distrito Federal e pelos Municípios;     (Incluído pela Emenda Constitucional nº 132, de 2023)
# V - a fiscalização, o lançamento, a cobrança, a representação administrativa e a representação judicial relativos ao imposto serão realizados, no âmbito de suas respectivas
# competências, pelas administrações tributá rias e procuradorias dos Estados, do Distrito Federal e dos Municípios, que poderão definir hipóteses de delegação ou de
# compartilhamento de competências, cabendo ao Comitê Gestor a coordenação dessas atividades administrativas com vistas à integração entre os entes federativos;     (Incluído
# pela Emenda Constitucional nº 132, de 2023)07/06/2024, 11:39 Constituição
# www.planalto.gov.br/ccivil_03/constituicao/constituicao.htm 117/226
# VI - as competências exclusivas das carreiras da administração tributária e das procuradorias dos Estados, do Distrito Federal e dos Municípios serão exercidas, no Comitê
# Gestor e na representação deste, por servidores das referidas carreiras;     (Incluído pela Emenda Constitucional nº 132, de 2023)
# VII - serão estabelecidas a estrutura e a gestão do Comitê Gestor , cabendo ao regimento interno dispor sobre sua organização e funcionamento.
#
# [Constituição Estadual SP]: NR)
# - "Caput" com redação dada pela Emenda Constitucional n° 19, de 14/04/2004. Parágrafo único - As atividades de representação judicial, consultoria e assessoramento jurídico das universidades públicas estaduais poderão
# ser realizadas ou supervisionadas, total ou parcialmente, pela Procuradoria Geral do Estado, na forma a ser estabelecida em convênio. ( NR)
# - Parágrafo único acrescentado pela Emenda Constitucional n° 19, de 14/04/2004.
#
# [Constituição Estadual SP]: SEÇÃO V
# Da Procuradoria da Assembleia Legislativa
# Artigo 30 - À Procuradoria da Assembleia Legislativa compete exercer a represe ntação judicial, a consultoria e o assessoramento técnico-
# jurídico do Poder Legislativo. Parágrafo único - Lei de iniciativa da Mesa da Assem bleia Legislativa organizará a Procuradoria da Assembleia Legislativa, observados os
# princípios e regras pertinentes da Constituição Federal e desta Constituição, disciplinará sua competência e disporá sobre o ingresso na classe
# inicial, mediante concurso público de provas e títulos. SEÇÃO VI
# Do T ribunal de Contas
# Artigo 31 - O Tribun al de Contas do Estado, integrado por sete Conselheiros, tem sede na Capital do Estado, quadro próprio de pessoal e
# jurisdição em todo o território estadual, exercendo, no que couber , as atribuições previstas no artigo 96 da Constituição Federal.
#
# [Constituição Estadual SP]: Artigo 29 - A matéria constante de projeto de lei rejeitado somente poderá ser renovada, na mesma sessão legislativa, mediante proposta da
# maioria absoluta dos membros da Assembleia Legislativa. ( NR)
# - Expressão "Ressalvados os projetos de iniciativa exclusiva", anteriormente constante deste artigo, declarada inconstitucional, em controle concentrado, pelo Supremo
# Tribunal Federal nos autos da ADI n° 1546. SEÇÃO V
# Da Procuradoria da Assembleia Legislativa
# Artigo 30 - À Procuradoria da Assembleia Legislativa compete exercer a represe ntação judicial, a consultoria e o assessoramento técnico-
# jurídico do Poder Legislativo.
#
# Question: Em quais hipóteses a Procuradoria Geral pode exercer a representação judicial e extrajudicial de servidores da UNICAMP?

# %%
teste_passagens
# Out:
# ['[Constituição Federal]: (Incluído pela Emenda Constitucional nº 45, de 2004)\n\uf24e  Art. 129. São funções institucionais do Ministério Público:07/06/2024, 11:39 Constituição\nwww.planalto.gov.br/ccivil_03/constituicao/constituicao.htm 91/226\nI - promover , privativamente, a ação penal pública, na forma da lei;\nII - zelar pelo efetivo respeito dos Poderes Públicos e dos serviços de relevância pública aos direitos assegurados nesta Constituição, promovendo as medidas necessárias\na sua garantia;\nIII - promover o inquérito civil e a ação civil pública, para a proteção do patrimônio público e social, do meio ambiente e de outros interesses difusos e coletivos;\nIV - promover a ação de inconstitucionalidade ou representação para fins de intervenção da União e dos Estados, nos casos previstos nesta Constituição;\nV - defender judicialmente os direitos e interesses das populações indígenas;\nVI - expedir notificações nos procedimentos administrativos de sua competência, requisitando informações e documentos para instruí-los, na forma da lei complementar\nrespectiva;\nVII - exercer o controle externo da atividade policial, na forma da lei complementar mencionada no artigo anterior;\nVIII - requisitar diligências investigatórias e a instauração de inquérito policial, indicados os fundamentos jurídicos de suas manifestações processuais;\nIX - exerce r outras funções que lhe forem conferidas, desde que compatíveis com sua finalidade, sendo-lhe vedada a representação judicial e a consultoria jurídica de\nentidades públicas. § 1º - A legitimação do Ministério Público para as ações civis previstas neste artigo  não impede a de terceiros, nas mesmas hipóteses, segundo o disposto nesta\nConstituição e na lei.',
#  '[Constituição Federal]: (Incluído pela Emenda Constitucional nº 132, de 2023)\n\uf24e  Art. 156-B.  Os Estados, o Distrito Federal e os Municípios exercerão de forma integrada, exclusivamente por meio do Comitê Gestor do Imposto sobre Bens e\nServiços, nos termos e limites estabelecidos nesta Constituição e em lei complementar , as seguintes competências administrativas relativas ao imposto de que trata o art. 156-\nA:     (Incluído pela Emenda Constitucional nº 132, de 2023)\nI - editar regulamento único e uniformizar a interpretação e a aplicação da legislação do imposto;     (Incluído pela Emenda Constitucional nº 132, de 2023)\nII - arrecadar o imposto, efetuar as comp ensações e distribuir o produto da arrecadação entre Estados, Distrito Federal e Municípios;     (Incluído pela Emenda\nConstitucional nº 132, de 2023)\nIII - decidir o contencioso administrativo. (Incluído pela Emenda Constitucional nº 132, de 2023)\n§ 1º O Com itê Gestor do Imposto sobre Bens e Serviços, entidade pública sob regime especial, terá independência técnica, administrativa, orçamentária e financeira. (Incluído pela Emenda Constitucional nº 132, de 2023)\n§ 2º Na forma da lei complementar:     (Incluído pela Emenda Constitucional nº 132, de 2023)\nI - os Estados, o Distri to Federal e os Municípios serão representados, de forma paritária, na instância máxima de deliberação do Comitê Gestor do Imposto sobre Bens e\nServiços;     (Incluído pela Emenda Constitucional nº 132, de 2023)\nII - será assegurada a alternância na presid ência do Comitê Gestor entre o conjunto dos Estados e o Distrito Federal e o conjunto dos Municípios e o Distrito Federal;    \n(Incluído pela Emenda Constitucional nº 132, de 2023)\nIII - o Comitê Gestor será financiado por percentual do produto da arrecadação do imposto destinado a cada ente federativo;     (Incluído pela Emenda Constitucional nº\n132, de 2023)\nIV - o controle externo do Comitê Gestor será exercido pelos Estados, pelo Distrito Federal e pelos Municípios;     (Incluído pela Emenda Constitucional nº 132, de 2023)\nV - a fiscalização, o lançamento, a cobrança, a representação administrativa e a representação judicial relativos ao imposto serão realizados, no âmbito de suas respectivas\ncompetências, pelas administrações tributá rias e procuradorias dos Estados, do Distrito Federal e dos Municípios, que poderão definir hipóteses de delegação ou de\ncompartilhamento de competências, cabendo ao Comitê Gestor a coordenação dessas atividades administrativas com vistas à integração entre os entes federativos;     (Incluído\npela Emenda Constitucional nº 132, de 2023)07/06/2024, 11:39 Constituição\nwww.planalto.gov.br/ccivil_03/constituicao/constituicao.htm 117/226\nVI - as competências exclusivas das carreiras da administração tributária e das procuradorias dos Estados, do Distrito Federal e dos Municípios serão exercidas, no Comitê\nGestor e na representação deste, por servidores das referidas carreiras;     (Incluído pela Emenda Constitucional nº 132, de 2023)\nVII - serão estabelecidas a estrutura e a gestão do Comitê Gestor , cabendo ao regimento interno dispor sobre sua organização e funcionamento.',
#  '[Constituição Estadual SP]: NR)\n- "Caput" com redação dada pela Emenda Constitucional n° 19, de 14/04/2004. Parágrafo único - As atividades de representação judicial, consultoria e assessoramento jurídico das universidades públicas estaduais poderão\nser realizadas ou supervisionadas, total ou parcialmente, pela Procuradoria Geral do Estado, na forma a ser estabelecida em convênio. ( NR)\n- Parágrafo único acrescentado pela Emenda Constitucional n° 19, de 14/04/2004.',
#  '[Constituição Estadual SP]: SEÇÃO V\nDa Procuradoria da Assembleia Legislativa\nArtigo 30 - À Procuradoria da Assembleia Legislativa compete exercer a represe ntação judicial, a consultoria e o assessoramento técnico-\njurídico do Poder Legislativo. Parágrafo único - Lei de iniciativa da Mesa da Assem bleia Legislativa organizará a Procuradoria da Assembleia Legislativa, observados os\nprincípios e regras pertinentes da Constituição Federal e desta Constituição, disciplinará sua competência e disporá sobre o ingresso na classe\ninicial, mediante concurso público de provas e títulos. SEÇÃO VI\nDo T ribunal de Contas\nArtigo 31 - O Tribun al de Contas do Estado, integrado por sete Conselheiros, tem sede na Capital do Estado, quadro próprio de pessoal e\njurisdição em todo o território estadual, exercendo, no que couber , as atribuições previstas no artigo 96 da Constituição Federal.',
#  '[Constituição Estadual SP]: Artigo 29 - A matéria constante de projeto de lei rejeitado somente poderá ser renovada, na mesma sessão legislativa, mediante proposta da\nmaioria absoluta dos membros da Assembleia Legislativa. ( NR)\n- Expressão "Ressalvados os projetos de iniciativa exclusiva", anteriormente constante deste artigo, declarada inconstitucional, em controle concentrado, pelo Supremo\nTribunal Federal nos autos da ADI n° 1546. SEÇÃO V\nDa Procuradoria da Assembleia Legislativa\nArtigo 30 - À Procuradoria da Assembleia Legislativa compete exercer a represe ntação judicial, a consultoria e o assessoramento técnico-\njurídico do Poder Legislativo.']

# %%
from groq import Groq

client = Groq(api_key='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')

def chat_completion(pergunta, n=5):
    # Documentação: https://console.groq.com/docs/text-chat
    messages = []
    # Adiciona as mensagens de sistema e few-shot
    messages.extend(initial_messages)
    # Sempre adiciona o prompt do usuário
    passagens = get_passagens(pergunta, n)
    user_message = mensagem_user(3, pergunta, passagens)
    messages.append({
        # Set a user message for the assistant to respond to.
        "role": "user",
        "content": user_message
    })
    chat_completion = client.chat.completions.create(
        messages=messages,

        # The language model which will generate the completion.
        model="llama3-70b-8192",

        # Controls randomness: lowering results in less random completions.
        # As the temperature approaches zero, the model will become deterministic
        # and repetitive.
        temperature=0,

        # The maximum number of tokens to generate. Requests can use up to
        # 32,768 tokens shared between prompt and completion.
        max_tokens=1024,

        # Controls diversity via nucleus sampling: 0.5 means half of all
        # likelihood-weighted options are considered.
        top_p=1,

        # A stop sequence is a predefined or user-specified text string that
        # signals an AI to stop generating content, ensuring its responses
        # remain focused and concise. Examples include punctuation marks and
        # markers like "[end]".
        stop=None,

        # If set, partial message deltas will be sent.
        stream=False,
    )
    # Retorna o texto da primeira mensagem e, caso seja necessário usar depois,
    # todo o objeto
    return chat_completion.choices[0].message.content, chat_completion

# %%
perg_resp_esperada_obtida = []

# %%
from tqdm import tqdm

def salvar_perg_resp_esperada_obtida(perg_resp_esperada_obtida):
  nome_arquivo = f"{'../input/Raw Text/Rag Data/'}{ARQUIVO_AGREGADO}"
  with open(nome_arquivo, 'wb') as f:
    pickle.dump(perg_resp_esperada_obtida, f)

def recuperar_perg_resp_esperada_obtida():
  nome_arquivo_base = f"{'../input/Raw Text/Rag Data/'}{ARQUIVO_AGREGADO}"
  perg_respostas = []
  with open(nome_arquivo_base, 'rb') as f:
    perg_respostas = pickle.load(f)
  return perg_respostas

# %%
import time

# Do jeito que foi implementado, se der problema (rate limit), basta executar a
# célula novamente. Ele vai continuar de onde parou
if AGREGAR_DOCUMENTOS:
  for perg_resp in tqdm(perg_resposta_esperada):
    pergunta = perg_resp['pergunta']
    resposta_esperada = perg_resp['resposta']
    resposta_obtida = chat_completion(pergunta)

    perg_resp_esperada_obtida.append({
        "pergunta": pergunta,
        "resposta_esperada": resposta_esperada,
        "resposta_obtida": resposta_obtida
    })
    time.sleep(5)
  salvar_perg_resp_esperada_obtida(perg_resp_esperada_obtida)
else:
  perg_resp_esperada_obtida = recuperar_perg_resp_esperada_obtida()
# Out:
# 100%|██████████| 50/50 [32:12<00:00, 38.66s/it]

# %%
salvar_perg_resp_esperada_obtida(perg_resp_esperada_obtida)

# %%
# Funções normize_answer e token_f1_score foram retiradas do Visconde (arquivo qasper_evaluator.py)
import re
import string

def normalize_answer(s):
  """
  Taken from the official evaluation script for v1.1 of the SQuAD dataset.
  Lower text and remove punctuation, articles and extra whitespace.
  """

  def remove_articles(text):
      return re.sub(r"\b(um|uma|o|a)\b", " ", text)

  def white_space_fix(text):
      return " ".join(text.split())

  def remove_punc(text):
      exclude = set(string.punctuation)
      return "".join(ch for ch in text if ch not in exclude)

  def lower(text):
      return text.lower()

  return white_space_fix(remove_articles(remove_punc(lower(s))))

def token_f1_score(prediction, ground_truth):
  """
  Taken from the official evaluation script for v1.1 of the SQuAD dataset.
  """
  prediction_tokens = normalize_answer(prediction).split()
  ground_truth_tokens = normalize_answer(ground_truth).split()
  common = Counter(prediction_tokens) & Counter(ground_truth_tokens)
  num_same = sum(common.values())
  if num_same == 0:
      return 0
  precision = 1.0 * num_same / len(prediction_tokens)
  recall = 1.0 * num_same / len(ground_truth_tokens)
  f1 = (2 * precision * recall) / (precision + recall)
  return f1

def extrai_resposta(resp):
  idx_resposta_llm = resp.find('Answer: ') + 8
  return resp[idx_resposta_llm:]


# Trata respostas vazias do GPT-3.5
def uniformiza_resposta_vazia(resp):
  valores_possiveis = ["n/a", "it is not possible to determine", "no information in the documents", "no information provided", "none of the documents", "documents do not provide", "unknown", "cannot be answered", "not mentioned", "not specified", "n/a", "not available", "insufficient data", "not enough information", "cannot be determined", "there is no mention", "no information available"]

  if resp == '':
    return 'none'

  resp = resp.lower()

  for valor_none in valores_possiveis:
    if valor_none in resp:
      return 'none'

  return resp

# %%
import pandas as pd

col_queries = []
col_resp_esperadas = []
col_respostas_llm = []
col_f1_score = []
col_em_score = []

for perg_respostas in perg_resp_esperada_obtida:
  query = perg_respostas['pergunta']
  resposta_esperada = normalize_answer(perg_respostas['resposta_esperada'])
  resposta_llm = normalize_answer(uniformiza_resposta_vazia(extrai_resposta(perg_respostas['resposta_obtida'][0])))
  #resposta_llm_2 = normalize_answer(uniformiza_resposta_vazia(perg_respostas['resposta_obtida']))
  #print(perg_respostas['resposta_obtida'])
  f1_score = token_f1_score(resposta_llm, resposta_esperada)
  em_score = 1 if resposta_llm == resposta_esperada else 0


  col_queries.append(query)
  col_resp_esperadas.append(resposta_esperada)
  col_respostas_llm.append(resposta_llm)
  col_f1_score.append(f1_score)
  col_em_score.append(em_score)

df = pd.DataFrame({'Query': col_queries, 'Resp_esperada': col_resp_esperadas, 'Resposta_LLM': col_respostas_llm, 'F1_score': col_f1_score, 'EM_score': col_em_score})
df
# Out:
#                                                 Query  \
# 0   Em quais hipóteses a Procuradoria Geral pode e...
# 1   Como ocorrem as atividades de cooperação, pesq...
# 2   Qual é o procedimento para a celebração de con...
# 3   Qual é o sistema utilizado para a tramitação d...
# 4           O que é o Plano de Aplicação de Recursos?
# 5   Quem pode ser executor de um convênio e quais ...
# 6   Quem é a autoridade competente para assinatura...
# 7   Existe uma tramitação simplificada para aprova...
# 8   Quando se deve utilizar um Termo Aditivo a um ...
# 9   É possível que o convênio preveja o pagamento ...
# 10  Como ocorre a tramitação de convênio com insti...
# 11  A execução foi concluída. Como se encerra o pr...
# 12  As manifestações emitidas por servidores, doce...
# 13  Qual procedimento deve ser adotado para utiliz...
# 14  Quais as condições e a forma de utilização da ...
# 15            É possível estilizar o logo da UNICAMP?
# 16  As unidades e órgãos universitários podem util...
# 17  As reuniões de órgãos colegiados da UNICAMP po...
# 18  As gravações podem ser disponibilizadas a terc...
# 19  As pautas, atas e deliberações dos órgãos cole...
# 20  Servidor técnico-administrativo da UNICAMP pod...
# 21  Docente da UNICAMP em RDIDP ou regime de dedic...
# 22  Como tramitam as sindicâncias administrativas ...
# 23  Em quais hipóteses deve ser instaurada sindicâ...
# 24  Quem tem competência para instaurar sindicânci...
# 25            Como deve ser a composição da Comissão?
# 26         Qual o prazo de funcionamento da Comissão?
# 27  Há ordem específica para oitiva dos investigad...
# 28  Ao final da apuração, como deve proceder a Com...
# 29  Durante o período de suspensão das atividades ...
# 30  No caso de apuração de faltas disciplinares at...
# 31  Como saber qual procedimento deve ser instaurado?
# 32  Em se tratando de Sindicância Investigativa, c...
# 33  Quem coordenará o Grupo de Trabalho responsáve...
# 34  Quem é o responsável por decidir os recursos i...
# 35  Quem são os responsáveis pela coordenação das ...
# 36  Qual é o objetivo principal do 'Prêmio Tese De...
# 37  Quais são as competências atribuídas ao Escrit...
# 38           Quem pode admitir servidores na UNICAMP?
# 39  Quem são os novos membros designados para a Co...
# 40  Quais são os requisitos formais para que profe...
# 41  Quais são os membros constituintes do Conselho...
# 42  Quais são as principais funções do Conselho Su...
# 43  Quais são as condições e restrições impostas a...
# 44  Qual é a estrutura de duração e os requisitos ...
# 45  Quais são os órgãos superiores de administraçã...
# 46  Como é composto o Conselho Universitário da Un...
# 47  Como é estruturada a administração financeira ...
# 48  Quais são os objetivos e requisitos do Program...
# 49  Qual é a estrutura do Perfil Quantitativo Míni...
#
#                                         Resp_esperada  \
# 0   procuradoria geral da unicamp integra advocaci...
# 1   nos termos do art 1° da deliberação consua0162...
# 2   na unicamp celebração de convênios contratos e...
# 3   os documentos essenciais estão elencados no ar...
# 4   plano de aplicação de recursos é documento que...
# 5   nos termos do art 18 §1° da deliberação consua...
# 6   como regra autoridade competente para assinatu...
# 7   sim art 7º da deliberação consua0162022 estabe...
# 8   em razão da inexistência de única lei ou códig...
# 9   sim concessão de bolsas estímulo à inovação pe...
# 10  tramitação de convênio que só tenha fundação d...
# 11  encerramento do processo deverá ocorrer após a...
# 12  não nos termos da deliberação cada042003 os se...
# 13  resolução gr0282004 condiciona uso da marca un...
# 14  portaria gr0341995 dispõe sobre as condições e...
# 15  não nos termos da portaria gr0341995 marca fig...
# 16  nos termos do artigo 4º da portaria gr0341995 ...
# 17  as gravações das reuniões de órgãos colegiados...
# 18  quanto à divulgação dos áudios e vídeos das re...
# 19  nos termos da lei federal nº 125272011 pautas ...
# 20  servidor técnico administrativo da unicamp pod...
# 21  docente da unicamp em rdidp ou em regime de de...
# 22  as sindicâncias administrativas deverão tramit...
# 23  sindicância administrativa é meio de apuração ...
# 24  podem instaurar sindicância administrativa no ...
# 25  sindicância deverá ser instaurada mediante por...
# 26  sindicância deverá ser concluída em 30 trinta ...
# 27  em geral ordem de convocação dos depoentes é e...
# 28  ao final da apuração comissão de sindicância i...
# 29  sim nesse momento de suspensão das atividades ...
# 30  em se tratando de infrações disciplinares atri...
# 31  conforme previsto no artigo 235 do regimento g...
# 32  tratandose de sindicância investigativa artigo...
# 33  coordenador do grupo de trabalho designado par...
# 34  baseado na informação retirada do resolução gr...
# 35  documento deliberação cada0052023 menciona no ...
# 36  objetivo principal do prêmio tese destaque uni...
# 37  regulação manutenção de licenças normatização ...
# 38  as admissões dispensas e demais atos referente...
# 39  de acordo com portaria gr0272021 reitor da uni...
# 40  de acordo com resolução gr0172004 os requisito...
# 41  conselho de orientação para incubadoras de emp...
# 42  as principais funções do conselho superior do ...
# 43  de acordo com deliberação consua0152024 os par...
# 44  os cursos de mestrado e doutorado no programa ...
# 45  os órgãos superiores de administração da unive...
# 46  conselho universitário que é órgão deliberativ...
# 47  administração financeira e orçamentária da uni...
# 48  programa formativo intercultural para ingressa...
# 49  deliberação cada0092023 da universidade estadu...
#
#                                          Resposta_LLM  F1_score  EM_score
# 0   não há resposta pois não há menção à unicamp o...  0.176101         0
# 1   mediante celebração de convênios contratos e i...  0.340426         0
# 2   procedimento para celebração de convênios cont...  0.407407         0
# 3               processos administrativos eletrônicos  0.000000         0
# 4   plano de aplicação de recursos é documento que...  0.341463         0
# 5   os servidores ativos da unicamp de qualquer ca...  0.382353         0
# 6   as autoridades competentes para assinatura dos...  0.272727         0
# 7                                                 sim  0.009852         0
# 8   quando se deseja alterar os termos do convênio...  0.291971         0
# 9                                                 sim  0.010204         0
# 10  tramitação de convênio com instituição interna...  0.309278         0
# 11  processo de convênio é encerrado com encaminha...  0.133333         0
# 12                                                não  0.034483         0
# 13  utilização do logotipo da unicamp deve obedece...  0.272727         0
# 14  as condições e forma de utilização da marca un...  0.529412         0
# 15  não há informação suficiente para responder à ...  0.048780         0
# 16  sim mas apenas em caráter excepcional e após a...  0.156863         0
# 17                                                sim  0.000000         0
# 18  não as gravações não podem ser disponibilizada...  0.033058         0
# 19  não há evidência de que as pautas atas e delib...  0.106952         0
# 20  sim desde que não haja relação com finalidade ...  0.115207         0
# 21                                                não  0.005450         0
# 22  as sindicâncias administrativas no âmbito da u...  0.214286         0
# 23  quando docente infringe qualquer das disposiçõ...  0.054795         0
# 24  autoridade competente que determinou instauraç...  0.193548         0
# 25  composição da comissão de legislação e normas ...  0.254902         0
# 26  não há prazo de funcionamento da comissão espe...  0.052632         0
# 27  sim há recomendação para que sindicado seja ou...  0.206897         0
# 28                           elaborar relatório final  0.083333         0
# 29                                                sim  0.064516         0
# 30  apuração das infrações disciplinares do corpo ...  0.400000         0
# 31  se houver dúvida sobre natureza e gravidade da...  0.104348         0
# 32  sindicância investigativa é conduzida mediante...  0.217391         0
# 33                    prof drª emília wanda rutkowski  0.256410         0
# 34                 diretor executivo de administração  0.111111         0
# 35  presidente da comissão de graduação coordenado...  0.472222         0
# 36  reconhecer e premiar as teses de doutorado de ...  0.595745         0
# 37  as competências do escritório de produtos cont...  0.127660         0
# 38                                  reitor da unicamp  0.068966         0
# 39  dra patrícia regina kitaka e outros membros nã...  0.113208         0
# 40  concessão de autorização pelo diretor da unida...  0.339623         0
# 41  os membros constituintes do conselho de orient...  0.720930         0
# 42  aprovar projetos de pesquisa detalhados aprese...  0.085714         0
# 43  as condições e restrições impostas aos partici...  0.481481         0
# 44  estrutura de duração e os requisitos de conclu...  0.511278         0
# 45  os órgãos superiores de administração da unive...  0.882353         0
# 46  composição e os mandatos dos membros do consel...  0.330275         0
# 47  administração financeira e orçamentária da uni...  0.487805         0
# 48  os objetivos do profiivi são aprimorar polític...  0.270677         0
# 49  perfil quantitativo mínimo para ascensão aos n...  0.368000         0

# %%
perg_resp_esperada_obtida[3]
# Out:
# {'pergunta': 'Qual é o sistema utilizado para a tramitação dos convênios?',
#  'resposta_esperada': 'Os documentos essenciais estão elencados no art. 2º da Deliberação CONSU-A-016/2022. É importante que o Executor tenha em mente que estes são os documentos mínimos necessários, mas dependendo do objeto do convênio, outros documentos podem ser demandados. O processo do convênio deve se iniciar com o documento de apresentação da proposta elaborado por seu Executor, com a indicação dos motivos pelos quais apresenta a proposta e por que entende que sua celebração é conveniente e oportuna para a Universidade. A apresentação da proposta deve ser seguida dos demais documentos elencados no mencionado artigo 2º, além de outros documentos que forem pertinentes ao seu objeto. É importante que no sistema SIAD os documentos sejam incluídos separadamente e não num único arquivo. Sempre que o convênio fizer referência a um documento, este documento deverá ser incluído no processo, para que possa ser consultado. Quanto mais completa for a instrução do processo, mais célere será sua tramitação nas instâncias da Universidade.',
#  'resposta_obtida': ("Evidence: De acordo com o trecho 'As propostas de convênios, contratos e instrumentos similares relativos às atividades de cooperação, pesquisa, ensino, extensão e prestação de serviços a serem celebrados pela Universidade, aqui denominados pela forma geral “convênios”, terão início em processos administrativos eletrônicos abertos nas Unidades de Ensino e Pesquisa, Centros, Núcleos ou Órgãos onde a atividade principal será realizada...' de [Deliberação CONSU-A-016/2022], a tramitação dos convênios é feita por meio de processos administrativos eletrônicos.\n\nAnswer: Processos administrativos eletrônicos.",
#   ChatCompletion(choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChoiceMessage(content="Evidence: De acordo com o trecho 'As propostas de convênios, contratos e instrumentos similares relativos às atividades de cooperação, pesquisa, ensino, extensão e prestação de serviços a serem celebrados pela Universidade, aqui denominados pela forma geral “convênios”, terão início em processos administrativos eletrônicos abertos nas Unidades de Ensino e Pesquisa, Centros, Núcleos ou Órgãos onde a atividade principal será realizada...' de [Deliberação CONSU-A-016/2022], a tramitação dos convênios é feita por meio de processos administrativos eletrônicos.\n\nAnswer: Processos administrativos eletrônicos.", role='assistant', tool_calls=None))], id='chatcmpl-6f35f2c5-574c-4d07-b551-c3e33eb3f8cf', created=1719441747, model='llama3-70b-8192', object='chat.completion', system_fingerprint='fp_87cbfbbc4d', usage=Usage(completion_time=0.465714286, completion_tokens=163, prompt_time=1.065485036, prompt_tokens=4796, queue_time=None, total_time=1.531199322, total_tokens=4959), x_groq={'id': 'req_01j1bbdt8sfcdtztyazgrtqdh9'}))}

# %%
len(perg_resp_esperada_obtida)
# Out:
# 50
